# %% [markdown]
# # Detecting anomalies in noisy waveforms

# %% [markdown]
# This notebook aims to explore the potential of the Moku neural networks in detecting anomalies in several arbitrary, periodic, noisy waveforms. This notebook has explored training neural networks on Sinc, Gaussian, Exponential fall, and Custom waves, where 'Custom' is a predefined wave generated through a function.
#
# We will use a Moku device to capture the signal data, then train a neural network model that can later be deployed on the Moku for real-time anomaly detection by flagging areas where the reconstruction error is large.

# %% [markdown]
# # 1. Environment Setup

# %% [markdown]
# First we import the neccessary libraries

# %%
import csv
import os
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import shift

from tqdm.notebook import tqdm
from tensorflow.keras.optimizers import Adam

# set the seed for repeatability
np.random.seed(0)
# Out:
# 2025-11-17 14:10:57.931321: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-17 14:10:57.983064: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-17 14:10:59.174381: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
from moku.instruments import MultiInstrument, Oscilloscope, ArbitraryWaveformGenerator,PIDController

try:
    from moku.nn import LinnModel, save_linn
except ImportError:
    print("Moku library is not installed.")
    raise

# %% [markdown]
# Define some helper functions

# %%
def format_sampling_rate(rate):
    """Given a sampling rate in float number form, reformat it into a string with shorter notation"""
    if rate >= 1e6:
        return f"{rate/1e6:.2f} MHz"
    elif rate >= 1e3:
        return f"{rate/1e3:.2f} kHz"
    else:
        return f"{rate:.2f} Hz"
        
def save_data_to_csv(data_points, window_size, filename):
    """Save 1D data points into CSV file, splitting into fixed-size windows per row."""
    # Ensure all values are floats
    data_points = [float(x) for x in data_points]

    # Split data into consecutive windows of length window_size
    windows = []
    num_points = len(data_points)
    i = 0
    while i + window_size <= num_points:
        windows.append(data_points[i:i + window_size])
        i += window_size
    # Handle the last partial window (pad or adjust start to full length)
    if i < num_points:
        start = max(0, num_points - window_size)
        windows.append(data_points[start:num_points])

    # Determine next ID for data frames by counting existing rows in file
    file_exists = os.path.exists(filename)
    next_id = 0
    if file_exists:
        with open(filename, 'r', newline='') as file:
            reader = csv.reader(file)
            next(reader, None)  # skip header
            next_id = sum(1 for _ in reader)

    # Append new data windows to the CSV
    with open(filename, 'a', newline='') as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(['id', 'data'])  # write header if new file
        for w in windows:
            writer.writerow([next_id, ';'.join(f"{x:.6f}" for x in w)])
            next_id += 1

def load_data_from_csv(filename):
    """Load data windows from the CSV file back into a list of lists of float values."""
    data_windows = []
    with open(filename, 'r', newline='') as file:
        reader = csv.reader(file)
        header = next(reader, None)  # skip header if present
        for row in reader:
            if len(row) < 2:
                continue  # skip malformed rows
            # Each row's second column is a ';'-separated list of values
            values = [float(x) for x in row[1].split(';')]
            data_windows.append(values)
    return data_windows

def focal_mse_loss(prediction, target, gamma=2.5):
    """Given a prediction and the target, amplify larger errors more than smaller ones by raising the squared error to a power gamma"""
    error = prediction - target
    squared_error = error ** 2
    return squared_error ** gamma

# %% [markdown]
# # 2. Data Gathering

# %% [markdown]
# Here we specify the type of wave we are testing, useful for file naming and general clarity.

# %%
waveName = "Custom"

# %% [markdown]
# To gather anomaly-free noisy data of waveforms for training our models, one of the methods is to enter into multi-instrument mode on a Moku device, and create an experimental setup that generates the noisy data for us.

# %% [markdown]
# <center>
# <img src="Screenshots/Annotatedsetup1.png" width="500"/>
# </center>

# %% [markdown]
# Slot 1: Arbitrary Wave Generator - Generating the specified base wave
#
# Slot 2: PID Controller - Adding Gaussian Noise to the custom wave
#
# Slot 3: Oscilloscope - Generating Gaussian Noise to PID controller, and observing the output of the PID controller

# %% [markdown]
# We can gather data from the oscilloscope instrument from the setup above for training. But first we need to prepare a location on our system to save data to.

# %%
# Define output folder and base filename and wave name
output_folder = "./data/"
output_filename = f"{waveName}{"_training_noisy"}"

# Generate a unique filename with timestamp to avoid overwriting
timestamp = str(time.time()).split(".")[-1]
output_filename = f"{output_folder}{output_filename}_{timestamp}.csv"
print(f"Data will be saved in the file: {output_filename}" )

# Create the folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder created: {output_folder}")
else:
    print(f"Folder already exists: {output_folder}")
# Out:
# Data will be saved in the file: ./data/Custom_training_noisy_9384246.csv
# Folder already exists: ./data/

# %% [markdown]
# Now we are ready to connect to a Moku device and deploy the above multi-instrument setup through python.
#
# Let's find our Moku device IP.

# %%
! mokucli list

# %% [markdown]
# ```
# The above command should output a list of connected Moku devices with their name, serial, IP, etc. Ensure your Moku device is listed and reachable.
#
# ```

# %% [markdown]
# After finding your Moku device, we save its IP to a variable.

# %%
mokuDeviceIP = '10.1.xx.xxx'

# %% [markdown]
# Here we connect to a Moku device, and deploy the set-up as shown above.
#
# For each instrument in the configuration, we have provided a preset file with pre-configured settings. You may wish to change the settings or create your own preset instrument settings for any desired effect on the collected training data. Here is a guide on how to save your own preset instrument files.
#
# https://knowledge.liquidinstruments.com/en_US/how-to-save-and-upload-configuration-files
#
# Each waveform has its own preset arbitrary waveform generator instrument file, we can load them respectively using the `waveName` variabe

# %%
# Connect to the Moku device and enter multi-instrument context
mim = MultiInstrument(mokuDeviceIP, force_connect=True, platform_id=4)

# Deploy wave generator
waveGen = mim.set_instrument(1, ArbitraryWaveformGenerator)
wavGenPresetFileName = f"{"wavegen"}{waveName}{".mokuconf"}"
waveGen.load_settings(wavGenPresetFileName)

# Deploy PID controller
pid = mim.set_instrument(2, PIDController)
pid.load_settings(filename="PIDNoise.mokuconf")

# Deploy oscilloscope
osc = mim.set_instrument(3, Oscilloscope)
osc.generate_waveform(1, 'Noise',amplitude=0.5, frequency=10e3)

# Set the wire connections between instruments
connections = [dict(source="Input1", destination="Slot1InA"),
               dict(source="Slot1OutA", destination="Slot2InA"),
               dict(source="Slot3OutA", destination="Slot2InB"),
               dict(source="Slot2OutA", destination="Slot3InA"),
              dict(source="Slot3OutA", destination="Output1")]
mim.set_connections(connections=connections)

# Configure the Analog front-end settings of the Moku
mim.set_frontend(channel=1, impedance="50Ohm", coupling="DC", attenuation="20dB")
# Out:
# {'attenuation': '20dB', 'coupling': 'DC', 'impedance': '50Ohm'}

# %% [markdown]
# Capture the data and save it to the defined output folder

# %%
# Acquisition parameters
window_size = 100        # number of samples per frame (window length)
n_frames = 150         # number of frames to capture for dataset
t1 = 0.0                 # start time (seconds)
t2 = 0.02               # end time (seconds) for each frame
duration = t2 - t1

# Set the oscilloscope timebase for each frame capture
osc.set_timebase(t1, t2)

for i in tqdm(range(n_frames), desc="Saving data"):
    data = osc.get_data()
    save_data_to_csv(data["ch1"], window_size, filename=output_filename)
# Out:
# Saving data:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
# Compute and display the sampling rate based on captured data
sampling_rate = osc.get_samplerate()
print("Sampling rate:", format_sampling_rate(osc.get_samplerate()["sample_rate"]))

# Plot an example frame of the captured data
plt.figure(figsize=(12, 4))
plt.plot(data["time"], data["ch1"])
plt.title("Example Captured Waveform (one frame)")
plt.xlabel("Time (s)")
plt.ylabel("Voltage")
plt.grid(True)
plt.show()
# Out:
# Sampling rate: 612.75 kHz

# %% [markdown]
# # 3. Training the model

# %%
# Read the saved frames from CSV, and shuffle it
data = load_data_from_csv(output_filename)
np.random.shuffle(data)

# %%
# Split into training and testing datasets (80% train, 20% test)
split_index = int(len(data) * 0.8)
full_training_dataset = data[:split_index]
full_testing_dataset = data[split_index:]

print(f"N. of frames in the training dataset: {len(full_training_dataset)}")
print(f"N. of frames in the testing dataset: {len(full_testing_dataset)}")
# Out:
# N. of frames in the training dataset: 1320
# N. of frames in the testing dataset: 330

# %% [markdown]
# We define our model and create an early stopping configuration for faster trianing process.

# %%
quant_mod = LinnModel()
early_stopping_config = {
    'patience': 50,            # allow 50 epochs without improvement
    'restore_best_weights': True,
    'monitor':"val_loss"
}

# %%
frame_length = len(full_training_dataset[0])
print(f"Frame length: {frame_length}")

# Configure the model inputs/outputs (autoencoder: outputs = inputs)
quant_mod.set_training_data(training_inputs=full_training_dataset,
                             training_outputs=full_training_dataset,
                             scale=False)

# Define a simple autoencoder architecture: 
#  - encoder layers with 16,16 neurons (relu and tanh activation)
#  - final decoder layer with 'frame_length' neurons (linear activation)
# You may wish to change the model structure depending on the waveform type to
# improve model performance
model_definition = [    
    (16, 'relu'),
    (16, 'tanh'),
    (frame_length, 'linear')]


# Build the model and specify a learning rate
quant_mod.construct_model(model_definition, show_summary=True)
quant_mod.model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
# Out:
# Frame length: 100
# 2025-11-17 14:12:12.919995: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │         1,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer               │ (None, 16)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_1             │ (None, 16)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │         1,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_2             │ (None, 100)            │             0 │
# │ (OutputClipLayer)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,588 (14.02 KB)
#  Trainable params: 3,588 (14.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We can now train our model.

# %%
history = quant_mod.fit_model(
    epochs=450,
    es_config=early_stopping_config,
    validation_split=0.1,
    verbose=1
)
# Out:
# Value for restore missing. Using default:False.
# Epoch 1/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0118 - val_loss: 0.0098
# Epoch 2/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 3/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 4/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 5/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 6/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 7/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 8/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 9/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 10/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 11/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 12/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 13/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 14/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 15/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 16/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 17/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 18/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 19/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 20/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 21/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 22/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 23/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 24/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 25/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 26/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 27/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 28/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 29/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 30/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 31/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 32/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 33/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 34/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 35/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 36/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 37/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 38/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 39/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 40/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 41/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 42/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 43/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 44/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 45/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 46/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 47/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 48/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 49/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 50/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 51/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 52/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 53/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 54/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 55/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 56/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 57/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 58/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 59/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 60/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 61/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 62/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 63/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 64/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 65/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 66/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 67/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 68/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 9.9985e-04
# Epoch 69/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 9.9987e-04
# Epoch 70/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 9.9435e-04
# Epoch 71/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - val_loss: 9.9777e-04
# Epoch 72/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9915e-04 - val_loss: 9.9336e-04
# Epoch 73/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9961e-04 - val_loss: 9.9358e-04
# Epoch 74/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9588e-04 - val_loss: 9.9436e-04
# Epoch 75/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9468e-04 - val_loss: 9.9006e-04
# Epoch 76/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9305e-04 - val_loss: 9.9219e-04
# Epoch 77/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9419e-04 - val_loss: 9.8953e-04
# Epoch 78/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9219e-04 - val_loss: 9.8984e-04
# Epoch 79/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9073e-04 - val_loss: 9.8643e-04
# Epoch 80/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9014e-04 - val_loss: 9.8912e-04
# Epoch 81/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8989e-04 - val_loss: 9.8657e-04
# Epoch 82/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8856e-04 - val_loss: 9.8620e-04
# Epoch 83/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8776e-04 - val_loss: 9.8488e-04
# Epoch 84/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8684e-04 - val_loss: 9.8304e-04
# Epoch 85/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8662e-04 - val_loss: 9.8183e-04
# Epoch 86/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8515e-04 - val_loss: 9.8577e-04
# Epoch 87/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8537e-04 - val_loss: 9.8387e-04
# Epoch 88/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8312e-04 - val_loss: 9.8211e-04
# Epoch 89/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8413e-04 - val_loss: 9.8082e-04
# Epoch 90/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8245e-04 - val_loss: 9.8237e-04
# Epoch 91/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8277e-04 - val_loss: 9.8306e-04
# Epoch 92/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8332e-04 - val_loss: 9.8087e-04
# Epoch 93/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8127e-04 - val_loss: 9.8388e-04
# Epoch 94/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8132e-04 - val_loss: 9.8324e-04
# Epoch 95/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7976e-04 - val_loss: 9.8229e-04
# Epoch 96/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7902e-04 - val_loss: 9.8238e-04
# Epoch 97/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7988e-04 - val_loss: 9.8143e-04
# Epoch 98/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7851e-04 - val_loss: 9.8045e-04
# Epoch 99/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7896e-04 - val_loss: 9.8274e-04
# Epoch 100/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7999e-04 - val_loss: 9.8157e-04
# Epoch 101/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7868e-04 - val_loss: 9.7931e-04
# Epoch 102/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7901e-04 - val_loss: 9.7826e-04
# Epoch 103/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7831e-04 - val_loss: 9.8267e-04
# Epoch 104/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7664e-04 - val_loss: 9.8076e-04
# Epoch 105/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7950e-04 - val_loss: 9.8288e-04
# Epoch 106/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7571e-04 - val_loss: 9.7882e-04
# Epoch 107/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7626e-04 - val_loss: 9.8191e-04
# Epoch 108/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7614e-04 - val_loss: 9.8082e-04
# Epoch 109/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7490e-04 - val_loss: 9.7982e-04
# Epoch 110/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7381e-04 - val_loss: 9.7959e-04
# Epoch 111/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7478e-04 - val_loss: 9.8082e-04
# Epoch 112/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7438e-04 - val_loss: 9.8104e-04
# Epoch 113/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7501e-04 - val_loss: 9.7915e-04
# Epoch 114/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7348e-04 - val_loss: 9.7864e-04
# Epoch 115/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7315e-04 - val_loss: 9.8011e-04
# Epoch 116/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7466e-04 - val_loss: 9.8095e-04
# Epoch 117/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7348e-04 - val_loss: 9.8007e-04
# Epoch 118/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7300e-04 - val_loss: 9.8010e-04
# Epoch 119/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7238e-04 - val_loss: 9.7832e-04
# Epoch 120/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7216e-04 - val_loss: 9.7942e-04
# Epoch 121/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7177e-04 - val_loss: 9.7845e-04
# Epoch 122/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7167e-04 - val_loss: 9.7784e-04
# Epoch 123/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7120e-04 - val_loss: 9.7881e-04
# Epoch 124/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7077e-04 - val_loss: 9.7845e-04
# Epoch 125/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7105e-04 - val_loss: 9.7860e-04
# Epoch 126/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7127e-04 - val_loss: 9.7694e-04
# Epoch 127/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7034e-04 - val_loss: 9.7825e-04
# Epoch 128/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6860e-04 - val_loss: 9.7770e-04
# Epoch 129/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6907e-04 - val_loss: 9.7548e-04
# Epoch 130/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6825e-04 - val_loss: 9.7805e-04
# Epoch 131/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6893e-04 - val_loss: 9.7899e-04
# Epoch 132/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6906e-04 - val_loss: 9.7686e-04
# Epoch 133/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6801e-04 - val_loss: 9.7640e-04
# Epoch 134/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6849e-04 - val_loss: 9.7802e-04
# Epoch 135/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6859e-04 - val_loss: 9.7746e-04
# Epoch 136/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6786e-04 - val_loss: 9.7871e-04
# Epoch 137/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6907e-04 - val_loss: 9.7787e-04
# Epoch 138/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6785e-04 - val_loss: 9.7789e-04
# Epoch 139/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6771e-04 - val_loss: 9.7684e-04
# Epoch 140/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6707e-04 - val_loss: 9.7678e-04
# Epoch 141/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6594e-04 - val_loss: 9.7626e-04
# Epoch 142/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6551e-04 - val_loss: 9.7708e-04
# Epoch 143/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6754e-04 - val_loss: 9.7857e-04
# Epoch 144/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6705e-04 - val_loss: 9.7663e-04
# Epoch 145/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6619e-04 - val_loss: 9.7804e-04
# Epoch 146/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6487e-04 - val_loss: 9.7769e-04
# Epoch 147/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6807e-04 - val_loss: 9.7973e-04
# Epoch 148/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6547e-04 - val_loss: 9.7551e-04
# Epoch 149/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6504e-04 - val_loss: 9.7553e-04
# Epoch 150/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6492e-04 - val_loss: 9.7650e-04
# Epoch 151/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6445e-04 - val_loss: 9.7588e-04
# Epoch 152/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6448e-04 - val_loss: 9.7386e-04
# Epoch 153/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6447e-04 - val_loss: 9.7588e-04
# Epoch 154/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6400e-04 - val_loss: 9.7493e-04
# Epoch 155/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6318e-04 - val_loss: 9.7459e-04
# Epoch 156/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6349e-04 - val_loss: 9.7597e-04
# Epoch 157/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6328e-04 - val_loss: 9.7611e-04
# Epoch 158/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6376e-04 - val_loss: 9.7754e-04
# Epoch 159/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6273e-04 - val_loss: 9.7556e-04
# Epoch 160/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6296e-04 - val_loss: 9.7384e-04
# Epoch 161/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6282e-04 - val_loss: 9.7376e-04
# Epoch 162/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6292e-04 - val_loss: 9.7558e-04
# Epoch 163/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6205e-04 - val_loss: 9.7355e-04
# Epoch 164/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6287e-04 - val_loss: 9.7613e-04
# Epoch 165/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6170e-04 - val_loss: 9.7380e-04
# Epoch 166/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6350e-04 - val_loss: 9.7513e-04
# Epoch 167/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6158e-04 - val_loss: 9.7256e-04
# Epoch 168/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6070e-04 - val_loss: 9.7404e-04
# Epoch 169/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6103e-04 - val_loss: 9.7319e-04
# Epoch 170/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6222e-04 - val_loss: 9.7487e-04
# Epoch 171/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6253e-04 - val_loss: 9.7440e-04
# Epoch 172/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6125e-04 - val_loss: 9.7394e-04
# Epoch 173/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6147e-04 - val_loss: 9.7626e-04
# Epoch 174/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6006e-04 - val_loss: 9.7350e-04
# Epoch 175/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6037e-04 - val_loss: 9.7421e-04
# Epoch 176/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6186e-04 - val_loss: 9.7272e-04
# Epoch 177/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5924e-04 - val_loss: 9.7442e-04
# Epoch 178/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6004e-04 - val_loss: 9.7229e-04
# Epoch 179/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6063e-04 - val_loss: 9.7284e-04
# Epoch 180/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6111e-04 - val_loss: 9.7221e-04
# Epoch 181/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5965e-04 - val_loss: 9.7488e-04
# Epoch 182/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6007e-04 - val_loss: 9.7606e-04
# Epoch 183/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6076e-04 - val_loss: 9.7289e-04
# Epoch 184/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6056e-04 - val_loss: 9.7512e-04
# Epoch 185/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5958e-04 - val_loss: 9.7450e-04
# Epoch 186/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6025e-04 - val_loss: 9.7318e-04
# Epoch 187/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5980e-04 - val_loss: 9.7162e-04
# Epoch 188/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5909e-04 - val_loss: 9.7289e-04
# Epoch 189/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5856e-04 - val_loss: 9.7493e-04
# Epoch 190/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6071e-04 - val_loss: 9.7459e-04
# Epoch 191/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5881e-04 - val_loss: 9.7525e-04
# Epoch 192/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5884e-04 - val_loss: 9.7488e-04
# Epoch 193/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5824e-04 - val_loss: 9.7354e-04
# Epoch 194/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5933e-04 - val_loss: 9.7439e-04
# Epoch 195/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6147e-04 - val_loss: 9.7440e-04
# Epoch 196/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5937e-04 - val_loss: 9.7084e-04
# Epoch 197/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5819e-04 - val_loss: 9.7383e-04
# Epoch 198/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5824e-04 - val_loss: 9.7079e-04
# Epoch 199/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5799e-04 - val_loss: 9.7160e-04
# Epoch 200/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6183e-04 - val_loss: 9.7164e-04
# Epoch 201/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5818e-04 - val_loss: 9.7205e-04
# Epoch 202/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5708e-04 - val_loss: 9.7352e-04
# Epoch 203/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5767e-04 - val_loss: 9.7092e-04
# Epoch 204/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5833e-04 - val_loss: 9.7290e-04
# Epoch 205/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5723e-04 - val_loss: 9.7290e-04
# Epoch 206/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5713e-04 - val_loss: 9.7055e-04
# Epoch 207/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5626e-04 - val_loss: 9.7210e-04
# Epoch 208/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5725e-04 - val_loss: 9.7118e-04
# Epoch 209/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5705e-04 - val_loss: 9.7077e-04
# Epoch 210/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5713e-04 - val_loss: 9.7111e-04
# Epoch 211/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5632e-04 - val_loss: 9.7370e-04
# Epoch 212/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5725e-04 - val_loss: 9.7316e-04
# Epoch 213/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5747e-04 - val_loss: 9.7071e-04
# Epoch 214/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5799e-04 - val_loss: 9.7027e-04
# Epoch 215/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5934e-04 - val_loss: 9.7069e-04
# Epoch 216/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5682e-04 - val_loss: 9.6872e-04
# Epoch 217/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5650e-04 - val_loss: 9.6971e-04
# Epoch 218/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5654e-04 - val_loss: 9.7145e-04
# Epoch 219/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5580e-04 - val_loss: 9.7062e-04
# Epoch 220/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5597e-04 - val_loss: 9.7288e-04
# Epoch 221/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5742e-04 - val_loss: 9.6924e-04
# Epoch 222/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5540e-04 - val_loss: 9.7015e-04
# Epoch 223/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5607e-04 - val_loss: 9.6972e-04
# Epoch 224/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5721e-04 - val_loss: 9.7085e-04
# Epoch 225/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5573e-04 - val_loss: 9.6958e-04
# Epoch 226/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5447e-04 - val_loss: 9.7014e-04
# Epoch 227/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5569e-04 - val_loss: 9.6889e-04
# Epoch 228/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5478e-04 - val_loss: 9.7010e-04
# Epoch 229/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5585e-04 - val_loss: 9.6967e-04
# Epoch 230/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5567e-04 - val_loss: 9.7125e-04
# Epoch 231/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5577e-04 - val_loss: 9.7251e-04
# Epoch 232/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5563e-04 - val_loss: 9.6884e-04
# Epoch 233/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5578e-04 - val_loss: 9.7083e-04
# Epoch 234/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5489e-04 - val_loss: 9.6918e-04
# Epoch 235/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5455e-04 - val_loss: 9.6914e-04
# Epoch 236/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5511e-04 - val_loss: 9.6978e-04
# Epoch 237/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5572e-04 - val_loss: 9.7215e-04
# Epoch 238/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5507e-04 - val_loss: 9.7230e-04
# Epoch 239/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5583e-04 - val_loss: 9.7258e-04
# Epoch 240/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5470e-04 - val_loss: 9.6820e-04
# Epoch 241/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5455e-04 - val_loss: 9.6907e-04
# Epoch 242/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5542e-04 - val_loss: 9.7122e-04
# Epoch 243/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5490e-04 - val_loss: 9.7005e-04
# Epoch 244/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5576e-04 - val_loss: 9.6765e-04
# Epoch 245/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5456e-04 - val_loss: 9.6865e-04
# Epoch 246/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5522e-04 - val_loss: 9.6851e-04
# Epoch 247/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5497e-04 - val_loss: 9.6764e-04
# Epoch 248/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5403e-04 - val_loss: 9.7061e-04
# Epoch 249/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5480e-04 - val_loss: 9.7061e-04
# Epoch 250/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5614e-04 - val_loss: 9.6902e-04
# Epoch 251/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5445e-04 - val_loss: 9.6953e-04
# Epoch 252/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5523e-04 - val_loss: 9.7036e-04
# Epoch 253/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5491e-04 - val_loss: 9.7174e-04
# Epoch 254/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5598e-04 - val_loss: 9.6862e-04
# Epoch 255/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5540e-04 - val_loss: 9.6743e-04
# Epoch 256/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5448e-04 - val_loss: 9.6901e-04
# Epoch 257/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5381e-04 - val_loss: 9.6798e-04
# Epoch 258/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5366e-04 - val_loss: 9.6785e-04
# Epoch 259/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5444e-04 - val_loss: 9.6773e-04
# Epoch 260/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5387e-04 - val_loss: 9.6991e-04
# Epoch 261/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5700e-04 - val_loss: 9.6837e-04
# Epoch 262/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5366e-04 - val_loss: 9.6805e-04
# Epoch 263/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5558e-04 - val_loss: 9.6983e-04
# Epoch 264/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5415e-04 - val_loss: 9.6946e-04
# Epoch 265/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5412e-04 - val_loss: 9.6859e-04
# Epoch 266/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5428e-04 - val_loss: 9.6806e-04
# Epoch 267/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5561e-04 - val_loss: 9.6759e-04
# Epoch 268/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5406e-04 - val_loss: 9.6851e-04
# Epoch 269/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5381e-04 - val_loss: 9.7128e-04
# Epoch 270/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5536e-04 - val_loss: 9.6794e-04
# Epoch 271/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5368e-04 - val_loss: 9.6741e-04
# Epoch 272/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5426e-04 - val_loss: 9.6701e-04
# Epoch 273/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5289e-04 - val_loss: 9.6931e-04
# Epoch 274/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5337e-04 - val_loss: 9.6609e-04
# Epoch 275/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5277e-04 - val_loss: 9.6621e-04
# Epoch 276/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5485e-04 - val_loss: 9.6625e-04
# Epoch 277/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5413e-04 - val_loss: 9.7102e-04
# Epoch 278/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5462e-04 - val_loss: 9.6831e-04
# Epoch 279/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5446e-04 - val_loss: 9.6965e-04
# Epoch 280/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5431e-04 - val_loss: 9.6787e-04
# Epoch 281/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5297e-04 - val_loss: 9.6738e-04
# Epoch 282/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5309e-04 - val_loss: 9.6670e-04
# Epoch 283/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5304e-04 - val_loss: 9.6743e-04
# Epoch 284/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5281e-04 - val_loss: 9.7037e-04
# Epoch 285/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5279e-04 - val_loss: 9.6578e-04
# Epoch 286/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5295e-04 - val_loss: 9.6650e-04
# Epoch 287/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5237e-04 - val_loss: 9.6660e-04
# Epoch 288/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5267e-04 - val_loss: 9.6562e-04
# Epoch 289/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5239e-04 - val_loss: 9.6704e-04
# Epoch 290/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5250e-04 - val_loss: 9.6788e-04
# Epoch 291/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5244e-04 - val_loss: 9.6844e-04
# Epoch 292/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5341e-04 - val_loss: 9.6844e-04
# Epoch 293/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5408e-04 - val_loss: 9.6819e-04
# Epoch 294/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5331e-04 - val_loss: 9.6766e-04
# Epoch 295/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5253e-04 - val_loss: 9.6601e-04
# Epoch 296/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5230e-04 - val_loss: 9.6617e-04
# Epoch 297/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5182e-04 - val_loss: 9.6717e-04
# Epoch 298/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5231e-04 - val_loss: 9.6905e-04
# Epoch 299/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5313e-04 - val_loss: 9.6609e-04
# Epoch 300/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5422e-04 - val_loss: 9.6680e-04
# Epoch 301/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5156e-04 - val_loss: 9.6850e-04
# Epoch 302/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5181e-04 - val_loss: 9.6559e-04
# Epoch 303/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5261e-04 - val_loss: 9.6710e-04
# Epoch 304/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5266e-04 - val_loss: 9.6809e-04
# Epoch 305/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5254e-04 - val_loss: 9.6644e-04
# Epoch 306/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5279e-04 - val_loss: 9.6633e-04
# Epoch 307/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5242e-04 - val_loss: 9.6559e-04
# Epoch 308/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5257e-04 - val_loss: 9.6622e-04
# Epoch 309/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5323e-04 - val_loss: 9.6775e-04
# Epoch 310/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5236e-04 - val_loss: 9.6688e-04
# Epoch 311/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5266e-04 - val_loss: 9.6616e-04
# Epoch 312/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5180e-04 - val_loss: 9.6648e-04
# Epoch 313/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5156e-04 - val_loss: 9.6597e-04
# Epoch 314/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5246e-04 - val_loss: 9.6637e-04
# Epoch 315/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5186e-04 - val_loss: 9.6934e-04
# Epoch 316/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5307e-04 - val_loss: 9.6633e-04
# Epoch 317/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5304e-04 - val_loss: 9.6791e-04
# Epoch 318/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5237e-04 - val_loss: 9.6327e-04
# Epoch 319/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5145e-04 - val_loss: 9.6610e-04
# Epoch 320/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5180e-04 - val_loss: 9.6634e-04
# Epoch 321/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5130e-04 - val_loss: 9.6676e-04
# Epoch 322/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5157e-04 - val_loss: 9.6666e-04
# Epoch 323/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5264e-04 - val_loss: 9.6781e-04
# Epoch 324/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5202e-04 - val_loss: 9.6531e-04
# Epoch 325/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5223e-04 - val_loss: 9.6386e-04
# Epoch 326/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5262e-04 - val_loss: 9.6730e-04
# Epoch 327/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5205e-04 - val_loss: 9.6450e-04
# Epoch 328/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5138e-04 - val_loss: 9.6471e-04
# Epoch 329/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5174e-04 - val_loss: 9.6642e-04
# Epoch 330/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5242e-04 - val_loss: 9.6871e-04
# Epoch 331/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5244e-04 - val_loss: 9.6708e-04
# Epoch 332/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5187e-04 - val_loss: 9.6527e-04
# Epoch 333/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5098e-04 - val_loss: 9.6544e-04
# Epoch 334/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5229e-04 - val_loss: 9.6704e-04
# Epoch 335/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5228e-04 - val_loss: 9.6799e-04
# Epoch 336/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5240e-04 - val_loss: 9.6466e-04
# Epoch 337/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5133e-04 - val_loss: 9.6677e-04
# Epoch 338/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5196e-04 - val_loss: 9.6480e-04
# Epoch 339/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5210e-04 - val_loss: 9.6815e-04
# Epoch 340/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5181e-04 - val_loss: 9.6646e-04
# Epoch 341/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5109e-04 - val_loss: 9.6501e-04
# Epoch 342/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5184e-04 - val_loss: 9.6499e-04
# Epoch 343/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5260e-04 - val_loss: 9.6576e-04
# Epoch 344/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5308e-04 - val_loss: 9.6454e-04
# Epoch 345/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5150e-04 - val_loss: 9.6609e-04
# Epoch 346/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5214e-04 - val_loss: 9.6490e-04
# Epoch 347/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4999e-04 - val_loss: 9.6481e-04
# Epoch 348/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5162e-04 - val_loss: 9.6477e-04
# Epoch 349/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5206e-04 - val_loss: 9.6568e-04
# Epoch 350/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5206e-04 - val_loss: 9.6569e-04
# Epoch 351/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5135e-04 - val_loss: 9.6441e-04
# Epoch 352/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5064e-04 - val_loss: 9.6627e-04
# Epoch 353/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5052e-04 - val_loss: 9.6513e-04
# Epoch 354/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5110e-04 - val_loss: 9.6624e-04
# Epoch 355/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5215e-04 - val_loss: 9.6668e-04
# Epoch 356/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5159e-04 - val_loss: 9.6613e-04
# Epoch 357/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5169e-04 - val_loss: 9.6382e-04
# Epoch 358/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5082e-04 - val_loss: 9.6565e-04
# Epoch 359/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5217e-04 - val_loss: 9.6600e-04
# Epoch 360/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5142e-04 - val_loss: 9.6462e-04
# Epoch 361/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5176e-04 - val_loss: 9.6510e-04
# Epoch 362/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5105e-04 - val_loss: 9.6576e-04
# Epoch 363/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5085e-04 - val_loss: 9.6514e-04
# Epoch 364/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5049e-04 - val_loss: 9.6719e-04
# Epoch 365/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5231e-04 - val_loss: 9.6377e-04
# Epoch 366/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5087e-04 - val_loss: 9.6496e-04
# Epoch 367/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5035e-04 - val_loss: 9.6569e-04
# Epoch 368/450
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5098e-04 - val_loss: 9.6611e-04

# %%
plt.semilogy(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train loss', 'val loss'])
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.show()

# %% [markdown]
# # 4. Saving the model

# %% [markdown]
# After training is complete, we can save the model to our current working directory.

# %%
model_filename = f"AD_{waveName}_model_Large_Noisy_{timestamp}.linn"
# Create a time-base array for mapping (same length as frame)
T = np.linspace(-1, 1, frame_length)
# Save the trained model to file
save_linn(quant_mod, input_channels=1, output_channels=1,
          file_name=model_filename, output_mapping=[T.size-1])
# Out:
# Skipping layer 0 with type <class 'keras.src.layers.core.input_layer.InputLayer'>
# Skipping layer 2 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 4 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 6 with type <class 'moku.nn._linn.OutputClipLayer'>
# Network latency approx. 141 cycles

# %% [markdown]
# # 5. Evaluate model reconstruction performance

# %% [markdown]
# Before moving to anomaly detection, we first evaluate the model's performance on reconstructing the original signal for the testing dataset

# %%
full_testing_dataset_np = np.array(full_testing_dataset)
reconstructions_test = quant_mod.predict(full_testing_dataset_np)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
frame_id = 2 # for example, take the third testing frame
plt.figure(figsize=(12, 4))
plt.plot(full_testing_dataset[frame_id], label='Original')
plt.plot(reconstructions_test[frame_id], label='Reconstruction', linestyle='--')
plt.legend()
plt.title('Original vs Reconstructed Signal')
plt.xlabel('Timestep within Frame')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
original = np.array(full_testing_dataset_np)
reconstructed = np.array(reconstructions_test)

# --- Error calculations ---
# Absolute error for each sample
absolute_error = np.abs(original - reconstructed)
# Squared error for each sample
squared_error = (original - reconstructed) ** 2

# Summed error per frame (could be used as an anomaly score per frame)
absolute_error_per_frame = absolute_error.sum(axis=1)
squared_error_per_frame = squared_error.sum(axis=1)

# %% [markdown]
# Get the MSE of the testing dataset

# %%
print(f"{"MSE: "}{np.mean(squared_error_per_frame)}")
# Out:
# MSE: 0.09788388571490293

# %% [markdown]
# # 6. Artificial anomaly detection

# %% [markdown]
# Now we are going to test the model's performance on detecting artificially inserted anomalies.
#
# To do this, we insert random anomalous data points into frames 52-57 of the testing data set, at index 3-8 of each of those frames, replacing the original data points.
#
# Then we run the model prediction on this new dataset.

# %%
full_testing_dataset_npAnom = full_testing_dataset_np.copy()
for i in range(52, 58):
    a = np.random.rand(5) * 0.5
    full_testing_dataset_npAnom[i,3:8] = a
reconstructions_test_anom = quant_mod.predict(full_testing_dataset_npAnom)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# We can now compare how the model reconstructs the signal with and without anomalies for same data frame.

# %%
# Take any frame within 52-57 range with the anomaly
example_frame_id = 55

# Plot original vs reconstructed for the anomalous frame
plt.figure(figsize=(12, 4))
plt.plot(full_testing_dataset_npAnom[example_frame_id], label='Original')
plt.plot(reconstructions_test_anom[example_frame_id], label='Reconstruction', linestyle='--')
plt.legend()
plt.title('Original vs Reconstructed Signal (Anomalous frame)')
plt.xlabel('Timestep within Frame')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot original vs reconstructed for the same frame without the artifical anomaly
plt.figure(figsize=(12, 4))
plt.plot(full_testing_dataset_np[example_frame_id], label='Original')
plt.plot(reconstructions_test[example_frame_id], label='Reconstruction', linestyle='--')
plt.legend()
plt.title('Original vs Reconstructed Signal (Normal frame)')
plt.xlabel('Timestep within Frame')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Anomaly detection on Moku device

# %% [markdown]
# To see the model's anomaly detection performance on a Moku device, we can deploy it into a multi-instrument context, with the following configuration.

# %% [markdown]
# <center>
# <figure>
# <img src="Screenshots/AD_MIM.png" alt="MIM" width="600">
# <figcaption>Multi-Instrument Config</figcaption>
# </figure>
# </center>
#
# <center>
# <figure>
# <img src="Screenshots/AD_AWG.png" alt="AWG" width="600">
# <figcaption>Arbitrary Wave Generator Config</figcaption>
# </figure>
# </center>
#
# <center>
# <figure>
# <img src="Screenshots/AD_AWG2.png" alt="AWG_Func" width="600">
# <figcaption>Generator Function with Anomaly</figcaption>
# </figure>
# </center>
#
# <center>
# <figure>
# <img src="Screenshots/AD_PID.png" alt="PID" width="600">
# <figcaption>PID Config</figcaption>
# </figure>
# </center>
#
# <center>
# <figure>
# <img src="Screenshots/AD_NN.png" alt="NN" width="600">
# <figcaption>Loaded Neural Network Model</figcaption>
# </figure>
# </center>
#
# <center>
# <figure>
# <img src="Screenshots/AD_OSC.png" alt="OSC" width="600">
# <figcaption>Oscilloscope with Math function</figcaption>
# </figure>
# </center>

# %% [markdown]
# We can now directly perform analysis on the recorded waveform data from the oscilloscope. Here is a guide on how to gather the data yourself.
#
# https://knowledge.liquidinstruments.com/en_US/data-logger/how-do-i-export-measured-data-from-my-moku
#
# We also have provided a sample data.

# %%
dataPath = "CustomWaveSquaredErrors_20251028_130356_Traces.csv"

# Skip text configuration lines to go directly to data
numberOfHeaderLines = 12

# %% [markdown]
# We read the data into python lists.

# %%
# Arbitrary time (x-axis)
time = []
# Neural net output
neuralNet = []
# Original wave + anomaly
noisyWave = []
# Math function output
originalSquaredError = []

with open(dataPath, mode ='r')as file:
    csvFile = csv.reader(file)
    for i in range (numberOfHeaderLines):    
        next(csvFile)
    for lines in csvFile:
        time.append(float(lines[0]))
        neuralNet.append(float(lines[1]))
        noisyWave.append(float(lines[2]))
        originalSquaredError.append(float(lines[3]))

time = np.array(time)
neuralNet = np.array(neuralNet)
noisyWave = np.array(noisyWave)
originalSquaredError = np.array(originalSquaredError)

# %% [markdown]
# Sometimes the neural network output is delayed by a few cycles and causes a phase shift in the neural network output data, which interferes with evaluating the model's anomaly detection performance metrics. So we can adjust for the phase shift here in python.

# %%
# Adjust phase shift using this value
phaseShiftAmount = -3

neuralNet =  shift(neuralNet, phaseShiftAmount, cval=0)

# %%
plt.figure(figsize=(12, 4))
plt.plot(time, neuralNet, label = "Neural Network Output")
plt.plot(time, noisyWave, label = "Noisy Wave")
plt.title("Neural Net recreation vs Original Noisy Wave (After Phase Shift)")
plt.xlabel("Time (s)")
plt.ylabel("Voltage")
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 4))
plt.title("Calculated Squared Error (After Phase Shift)")
plt.xlabel("Time (s)")
plt.ylabel("Voltage")
plt.plot(time, (neuralNet - noisyWave)**2, label = "SE", color='red')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(f"{"MSE: "}{np.mean((neuralNet - noisyWave)**2)}")
# Out:
# MSE: 0.001314972320217164

# %%
# Compute focal loss
focal_loss = focal_mse_loss(neuralNet, noisyWave)

plt.figure(figsize=(12, 4))
plt.plot(focal_loss, label='Frame with anomaly', color='orange')
plt.title('Reconstruction Focal Loss')
plt.xlabel('Timestep within Frame')
plt.ylabel('Error')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Additional Information

# %% [markdown]
# You may choose to continue experimenting on anomaly detection on other waveforms, as we have provided additional instrument configuration files for Sinc, Gaussian and ExponentialFall Wave types.
#
# To change the waveform, simply change the `waveName` variable at the start of Section 2 to one of the stated waves, or you may wish to create your own.
