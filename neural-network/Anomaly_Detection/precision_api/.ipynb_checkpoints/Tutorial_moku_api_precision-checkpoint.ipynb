# %% [markdown]
# ## 1. Prepare the environment

# %% [markdown]
# Optional: download all the python libraries if you not already present in the environment

# %%
! python.exe -m pip install --upgrade pip
! pip install --upgrade moku
! pip install zeroconf
# %pip install --q moku[neuralnetwork]
# Out:
# Requirement already satisfied: pip in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (25.1.1)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000217B707EC90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000217B707F590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000217B707FD90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000217B7094D50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000217B7095410>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# Requirement already satisfied: moku in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (3.3.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (from moku) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->moku) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->moku) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->moku) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->moku) (2024.8.30)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016DC7B72D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/moku/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016DC7B73450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/moku/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016DC7B73E90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/moku/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016DC7B80D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/moku/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000016DC7B81A50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/moku/
# Requirement already satisfied: zeroconf in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (0.147.0)
# Requirement already satisfied: ifaddr>=0.1.7 in c:\users\miche\appdata\local\programs\python\python311\lib\site-packages (from zeroconf) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import the Python libraries

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import moku
import numpy as np
import os
from pathlib import Path
from datetime import datetime
import time

# %%
from moku.instruments import MultiInstrument
from moku.instruments import WaveformGenerator, PIDController

try:
    from moku.nn import LinnModel, save_linn
except ImportError:
    print("Moku library is not installed.")
    print("If you're running in a Notebook like Google Colab, uncomment the first line in this cell and run it again")
    print("Otherwise install the moku library with neural network extensions using `pip install moku[neuralnetwork]`")
    raise

# %% [markdown]
# List the available moku devices

# %%
! mokucli list
# Out:
# Name                 Serial  HW     FW     IP
# ---------------------------------------------------------------

# %% [markdown]
# ## 2. Set up the Multi-instrument - data creation for training and testing datasets

# %%
def append_list_to_csv(data_list, filename):
    
    # Check if file exists
    file_exists = os.path.isfile(filename)
    print(file_exists)

    if not file_exists:
        with open(filename, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(data_list)

    else:
        # Open the file in append mode
        with open(filename, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(data_list)

# %%
def save_data_to_csv(data_points, window_size, filename):
    # Ensure all values are floats
    data_points = [float(x) for x in data_points]

    # Compute total number of windows
    windows = []
    num_points = len(data_points)
    i = 0

    while i + window_size <= num_points:
        windows.append(data_points[i:i + window_size])
        i += window_size

    # Handle the last partial window
    if i < num_points:
        # Start the last window earlier to make it full size
        start = max(0, num_points - window_size)
        windows.append(data_points[start:num_points])

    # Check if file exists and read current ID count
    file_exists = os.path.exists(filename)
    next_id = 0
    if file_exists:
        with open(filename, mode='r', newline='') as file:
            reader = csv.reader(file)
            next(reader, None)  # Skip header
            next_id = sum(1 for _ in reader)

    # Open file in append mode (create if doesn't exist)
    with open(filename, mode='a', newline='') as file:
        writer = csv.writer(file)

        # Write header if file is new
        if not file_exists:
            writer.writerow(['id', 'data'])

        # Write each window
        for w in windows:
            writer.writerow([next_id, ';'.join(f'{x:.6f}' for x in w)])
            next_id += 1

    print(f"Total n. of frames in the output file: {next_id}")

# %%
'''
Example to try

from moku.instruments import MultiInstrument, NeuralNetwork
m = MultiInstrument('192.168.###.###', platform_id=4)
nn = m.set_instrument(1, NeuralNetwork)
nn.set_input_sample_rate(300)
'''
# Out:
# "\nExample to try\n\nfrom moku.instruments import MultiInstrument, NeuralNetwork\nm = MultiInstrument('192.168.###.###', platform_id=4)\nnn = m.set_instrument(1, NeuralNetwork)\nnn.set_input_sample_rate(300)\n"

# %% [markdown]
# Set up the instruments

# %% [markdown]
# ### 2.2 Get the data from the PID controller and save it to local - FRAMES WITH ANOMALY

# %%
# Output filenames
output_folder = "AD_dataset/"
output_filename_anomaly = "data_anomaly"

timestamp = str(time.time()).split(".")[-1]

output_filename_anomaly = f"{output_folder}{output_filename_anomaly}_{timestamp}.csv"
print(f"Data will be saved in the file: {output_filename_anomaly}" )


# If the folder doesn't exist it, create it
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder created: {output_folder}")
else:
    print(f"Folder already exists: {output_folder}")
# Out:
# Data will be saved in the file: AD_dataset/data_anomaly_6606839.csv
# Folder already exists: AD_dataset/

# %%
# Replace in the code below the first input variable with your Moku IP adrress and platform id based on your Moku
m = MultiInstrument('10.1.119.245', platform_id=4, force_connect=True)

# %%
wg = m.set_instrument(1, WaveformGenerator)
pidc = m.set_instrument(2, PIDController)
wgmod = m.set_instrument(4, WaveformGenerator)

connections = [dict(source="Slot4OutA", destination="Slot1InA"),
                dict(source="Slot4OutB", destination="Slot1InB"),
                dict(source="Slot1OutA", destination="Slot2InA"),
                dict(source="Slot1OutB", destination="Slot2InB"),
                dict(source="Slot2OutA", destination="Output1")]

print(m.set_connections(connections=connections))

wg.generate_waveform(channel=1, type="Sine", frequency=400, amplitude=1.0)
wg.generate_waveform(channel=2, type='Noise', amplitude=1.0)
wg.set_modulation(channel=2, type="Amplitude", source="InputB", depth=1000)


# Try not to match the pulse glitch frequency with the sine wave's frequency or any of its multiplier
wgmod.generate_waveform(channel=2, type="Pulse", frequency=851, amplitude=1,
                        offset=410e-3, pulse_width=1e-6, edge_time=2e-9)

pidc.set_control_matrix(channel=1, input_gain1=1, input_gain2=20)
pidc.set_control_matrix(channel=2, input_gain1=0, input_gain2=0)


pidc.set_by_frequency(channel=1, prop_gain=0)
pidc.set_monitor(monitor_channel=2, source="Output1")
pidc.set_by_gain(channel=2, prop_gain=0)

# Enable the outputs of the PID controller
pidc.enable_output(1, signal=True, output=True)
pidc.enable_output(2, signal=True, output=False)
pidc.set_timebase(-15e-3, 15e-3)
# Out:
# [{'destination': 'Slot1InA', 'source': 'Slot4OutA'}, {'destination': 'Slot1InB', 'source': 'Slot4OutB'}, {'destination': 'Slot2InA', 'source': 'Slot1OutA'}, {'destination': 'Slot2InB', 'source': 'Slot1OutB'}, {'destination': 'Output1', 'source': 'Slot2OutA'}]
# {'t1': -0.015, 't2': 0.015}

# %%
window_size = 100
n_frames = 10

# %%
for i in range(n_frames):
    data = pidc.get_data() # Get the data from the PID controller

    # Set up the plotting parameters
    plt.ion()
    plt.show()
    plt.grid(visible=True)
    plt.ylim([-1, 1])
    plt.xlim([data['time'][0], data['time'][-1]])

    line1, = plt.plot([])
    line2, = plt.plot([])

    # Configure labels for axes
    ax = plt.gca()

    # This loops continuously updates the plot with new data
   
    # Update the plot
    line1.set_ydata(data['ch1'])
    line2.set_ydata(data['ch2'])
    line1.set_xdata(data['time'])
    line2.set_xdata(data['time'])


    print(f'{i} - Saved {len(data["ch2"])} points from the PID controller')
    save_data_to_csv(data["ch2"],window_size, filename=output_filename_anomaly)
# Out:
# 0 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 11
# 1 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 22
# 2 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 33
# 3 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 44
# 4 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 55
# 5 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 66
# 6 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 77
# 7 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 88
# 8 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 99
# 9 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 110

# %%
plt.plot(data['ch2'][:100])

# %% [markdown]
# ### 2.3 Get the data from the PID controller and save it to local - NORMAL FRAMES

# %%
# Output filenames
output_folder = "AD_dataset/"
output_filename_normal = "data_normal"

timestamp = str(time.time()).split(".")[-1]

output_filename_normal = f"{output_folder}{output_filename_normal}_{timestamp}.csv"
print(f"Data will be saved in the file: {output_filename_normal}" )


# If the folder doesn't exist it, create it
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder created: {output_folder}")
else:
    print(f"Folder already exists: {output_folder}")
# Out:
# Data will be saved in the file: AD_dataset/data_normal_0544436.csv
# Folder already exists: AD_dataset/

# %%
wg = m.set_instrument(1, WaveformGenerator)
pidc = m.set_instrument(2, PIDController)

connections = [dict(source="Slot4OutB", destination="Slot1InB"),
                dict(source="Slot1OutA", destination="Slot2InA"),
                dict(source="Slot1OutB", destination="Slot2InB"),
                dict(source="Slot2OutA", destination="Output1")]

print(m.set_connections(connections=connections))

wg.generate_waveform(channel=1, type="Sine", frequency=400, amplitude=1.0)
wg.generate_waveform(channel=2, type='Noise', amplitude=1.0)
wg.set_modulation(channel=2, type="Amplitude", source="InputB", depth=1000)

pidc.set_control_matrix(channel=1, input_gain1=1, input_gain2=1)
pidc.set_control_matrix(channel=2, input_gain1=0, input_gain2=0)


pidc.set_by_frequency(channel=1, prop_gain=0)
pidc.set_monitor(monitor_channel=2, source="Output1")
pidc.set_by_gain(channel=2, prop_gain=0)

# Enable the outputs of the PID controller
pidc.enable_output(1, signal=True, output=True)
pidc.enable_output(2, signal=True, output=False)
pidc.set_timebase(-15e-3, 15e-3)
# Out:
# [{'destination': 'Slot1InA', 'source': 'Slot4OutA'}, {'destination': 'Slot1InB', 'source': 'Slot4OutB'}, {'destination': 'Slot2InA', 'source': 'Slot1OutA'}, {'destination': 'Slot2InB', 'source': 'Slot1OutB'}, {'destination': 'Output1', 'source': 'Slot2OutA'}]
# {'t1': -0.015, 't2': 0.015}

# %%
window_size = 100
n_frames = 100

# %%
for i in range(n_frames):
    data = pidc.get_data() # Get the data from the PID controller

    print(f'{i} - Saved {len(data["ch2"])} points from the PID controller')
    save_data_to_csv(data["ch2"],window_size, filename=output_filename_normal)
# Out:
# 0 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 11
# 1 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 22
# 2 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 33
# 3 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 44
# 4 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 55
# 5 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 66
# 6 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 77
# 7 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 88
# 8 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 99
# 9 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 110
# 10 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 121
# 11 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 132
# 12 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 143
# 13 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 154
# 14 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 165
# 15 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 176
# 16 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 187
# 17 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 198
# 18 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 209
# 19 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 220
# 20 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 231
# 21 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 242
# 22 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 253
# 23 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 264
# 24 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 275
# 25 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 286
# 26 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 297
# 27 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 308
# 28 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 319
# 29 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 330
# 30 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 341
# 31 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 352
# 32 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 363
# 33 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 374
# 34 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 385
# 35 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 396
# 36 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 407
# 37 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 418
# 38 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 429
# 39 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 440
# 40 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 451
# 41 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 462
# 42 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 473
# 43 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 484
# 44 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 495
# 45 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 506
# 46 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 517
# 47 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 528
# 48 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 539
# 49 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 550
# 50 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 561
# 51 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 572
# 52 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 583
# 53 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 594
# 54 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 605
# 55 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 616
# 56 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 627
# 57 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 638
# 58 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 649
# 59 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 660
# 60 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 671
# 61 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 682
# 62 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 693
# 63 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 704
# 64 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 715
# 65 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 726
# 66 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 737
# 67 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 748
# 68 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 759
# 69 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 770
# 70 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 781
# 71 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 792
# 72 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 803
# 73 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 814
# 74 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 825
# 75 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 836
# 76 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 847
# 77 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 858
# 78 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 869
# 79 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 880
# 80 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 891
# 81 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 902
# 82 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 913
# 83 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 924
# 84 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 935
# 85 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 946
# 86 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 957
# 87 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 968
# 88 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 979
# 89 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 990
# 90 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1001
# 91 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1012
# 92 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1023
# 93 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1034
# 94 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1045
# 95 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1056
# 96 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1067
# 97 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1078
# 98 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1089
# 99 - Saved 1024 points from the PID controller
# Total n. of frames in the output file: 1100

# %% [markdown]
# ## 3. Compose the training dataset

# %%
def load_data_from_csv(filename):
    data_windows = []

    with open(filename, mode='r', newline='') as file:
        reader = csv.reader(file)
        header = next(reader, None)  # Skip header if it exists

        for row in reader:
            if len(row) < 2:
                continue  # Skip malformed rows
            # Split the 'data' field and convert back to floats
            float_values = [float(x) for x in row[1].split(';')]
            data_windows.append(float_values)

    return data_windows

# %%
# Read from the saved files
output_filename_anomaly = 'AD_dataset/data_anomaly_434809.csv'
output_filename_normal = 'AD_dataset/data_anomaly_0656183.csv'
data_anomaly = load_data_from_csv(output_filename_anomaly)
data_normal = load_data_from_csv(output_filename_normal)

# Split into training and testing set
data_anomaly_frames = int(len(data_anomaly)*0.8)
data_anomaly_training = data_anomaly[:data_anomaly_frames]
data_anomaly_testing = data_anomaly[data_anomaly_frames:]

data_normal_frames = int(len(data_normal)*0.8)
data_normal_training = data_normal[:data_normal_frames]
data_normal_testing = data_normal[data_normal_frames:]


print(f"N. of frames with anomaly in the training dataset: {len(data_anomaly_training)}")
print(f"N. of normal frames in the training dataset: {len(data_normal_training)}")

print(f"N. of frames with anomaly in the testing dataset: {len(data_anomaly_testing)}")
print(f"N. of normal frames in the testing dataset: {len(data_normal_testing)}")
# Out:
# N. of frames with anomaly in the training dataset: 176
# N. of normal frames in the training dataset: 88
# N. of frames with anomaly in the testing dataset: 44
# N. of normal frames in the testing dataset: 22

# %%
full_training_dataset = data_anomaly_training + data_normal_training
print(f"Total number of frames in the training dataset: {len(full_training_dataset)}")

full_testing_dataset = data_anomaly_testing + data_normal_testing
print(f"Total number of frames in the testing dataset: {len(full_testing_dataset)}")
# Out:
# Total number of frames in the training dataset: 264
# Total number of frames in the testing dataset: 66

# %% [markdown]
# Split the training dataset into training and validation sets.
# 80/20 split is used in this tutorial.

# %%
train_size = int(0.8 * len(full_training_dataset))
val_size = len(full_training_dataset) - train_size

indices = list(range(len(full_training_dataset)))


# Split the indices into training and validation sets
train_indices = indices[:train_size]
val_indices = indices[train_size:]

print(f"Tot n. of frames in the training dataset: {train_size}")
print(f"Tot n. of frames in the validation dataset: {val_size}")
# Out:
# Tot n. of frames in the training dataset: 211
# Tot n. of frames in the validation dataset: 53

# %%
# Create train and validation datasets with the generated indices
training_inputs = [full_training_dataset[i] for i in train_indices]
validation_inputs = [full_training_dataset[i] for i in val_indices]

# %% [markdown]
# TO DO: check anomalies in both the val and training dataset

# %% [markdown]
# ## 4. Define the model and train

# %%
quant_mod = LinnModel()

# %%
# Set up the early stopping - the below checks every 10 epochs 

early_stopping_config = {
    'patience': 10,   # Allow 10 epochs without improvement
    'restore_best_weights': True
}

# %%
# model definition for an autoencoder
frame_length = len(training_inputs[0])
print(f"frame length/input dimension: {frame_length}")

# train the model
quant_mod.set_training_data(training_inputs=training_inputs, training_outputs=training_inputs)
model_definition = [(64, 'relu'), (32, 'relu'), (16, 'relu'), (frame_length, 'linear')]

# build the model
#quant_mod.construct_model(model_definition, show_summary=True)
quant_mod.construct_model(model_definition)
# Out:
# frame length/input dimension: 100
# WARNING:tensorflow:From c:\Users\miche\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
history = quant_mod.fit_model(epochs=100, es_config=early_stopping_config, validation_split=0.1)
# Out:
# Value for monitor missing. Using default:val_loss.
# Value for restore missing. Using default:False.
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3838 - val_loss: 0.3626
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3605 - val_loss: 0.3478
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3450 - val_loss: 0.3329
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3280 - val_loss: 0.3149
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3134 - val_loss: 0.2965
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2924 - val_loss: 0.2771
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2743 - val_loss: 0.2569
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2553 - val_loss: 0.2362
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2335 - val_loss: 0.2154
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2093 - val_loss: 0.1950
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1886 - val_loss: 0.1742
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1701 - val_loss: 0.1551
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1520 - val_loss: 0.1379
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1369 - val_loss: 0.1231
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1215 - val_loss: 0.1102
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1081 - val_loss: 0.0985
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0962 - val_loss: 0.0872
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0871 - val_loss: 0.0769
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0766 - val_loss: 0.0676
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0680 - val_loss: 0.0594
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0580 - val_loss: 0.0522
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0524 - val_loss: 0.0458
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0462 - val_loss: 0.0402
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0405 - val_loss: 0.0355
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0370 - val_loss: 0.0315
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0328 - val_loss: 0.0281
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0297 - val_loss: 0.0252
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0263 - val_loss: 0.0227
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0238 - val_loss: 0.0207
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0221 - val_loss: 0.0189
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0203 - val_loss: 0.0174
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0193 - val_loss: 0.0160
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0174 - val_loss: 0.0149
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0164 - val_loss: 0.0140
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0155 - val_loss: 0.0132
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0144 - val_loss: 0.0125
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138 - val_loss: 0.0118
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0130 - val_loss: 0.0113
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127 - val_loss: 0.0108
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0104
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0116 - val_loss: 0.0100
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 0.0098
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0107 - val_loss: 0.0095
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105 - val_loss: 0.0092
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0105 - val_loss: 0.0090
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - val_loss: 0.0088
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - val_loss: 0.0087
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0096 - val_loss: 0.0085
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - val_loss: 0.0084
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0082
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0081
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0094 - val_loss: 0.0080
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092 - val_loss: 0.0079
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0088 - val_loss: 0.0078
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0077
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0077
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - val_loss: 0.0076
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082 - val_loss: 0.0076
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - val_loss: 0.0075
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - val_loss: 0.0075
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - val_loss: 0.0074
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0085 - val_loss: 0.0074
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - val_loss: 0.0074
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0084 - val_loss: 0.0074
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084 - val_loss: 0.0073
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077 - val_loss: 0.0073
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - val_loss: 0.0073
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - val_loss: 0.0072
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - val_loss: 0.0071
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0078 - val_loss: 0.0071
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0082 - val_loss: 0.0071
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085 - val_loss: 0.0071
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - val_loss: 0.0070
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - val_loss: 0.0070
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - val_loss: 0.0069
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079 - val_loss: 0.0069
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - val_loss: 0.0068

# %%
# plot the losses
plt.semilogy(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train loss', 'val loss'])
plt.xlabel('Epochs')
plt.show()

# %%
model_filename = 'AD_model_delete.linn'
save_linn(quant_mod, input_channels=1, output_channels=1, file_name=model_filename, output_mapping=[T.size-1])
# Out:
# Skipping layer 0 with type <class 'keras.src.layers.core.input_layer.InputLayer'>
# Skipping layer 2 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 4 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 6 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 8 with type <class 'moku.nn._linn.OutputClipLayer'>
# Network latency approx. 224 cycles

# %% [markdown]
# # 5. Testing the model - reconstruct the training dataset
# This is used to see how well the model has learnt to reconstruct the data from the training dataset

# %%
reconstructions = []
reconstructions = quant_mod.predict(full_testing_dataset)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %%
frame_id = 0

plt.figure(figsize=(12, 4))
plt.plot(full_training_dataset[frame_id], label='Original')
plt.plot(reconstructions[frame_id], label='Reconstruction', linestyle='--')
plt.legend()
plt.title('Original vs Reconstructed Signal')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6. Testing the model - reconstruct the testing dataset
# This is used to see how well the model generalize the signal reconstruction on never seens before waveforms.

# %%
reconstructions_test = []
reconstructions_test = quant_mod.predict(full_testing_dataset)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
frame_id_anomaly = 40
frame_id_normal = 0

plt.figure(figsize=(12, 4))
plt.plot(full_testing_dataset[frame_id_normal], label='Original')
plt.plot(reconstructions_test[frame_id_normal], label='Reconstruction', linestyle='--')
plt.legend()
plt.title('Original vs Reconstructed Signal')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Extract the reconstruction error

# %%
original = np.array(full_testing_dataset)
reconstructed = np.array(reconstructions_test)

# --- Error Calculations ---
# Element-wise absolute error
absolute_error = np.abs(original - reconstructed)

# Element-wise squared error
squared_error = (original - reconstructed) ** 2

# Total error per sample (row-wise)
absolute_error_per_frame = absolute_error.sum(axis=1)
squared_error_per_frame = squared_error.sum(axis=1)

# %% [markdown]
# #### Absolute error

# %%
# --- Plotting both frame_ids together ---
plt.figure(figsize=(12, 4))

plt.plot(absolute_error[frame_id_anomaly], label='Frame with anomaly', color='orange')
plt.plot(absolute_error[frame_id_normal], label='Normal Frame', color='blue')

plt.title('Absolute Error Comparison')
plt.xlabel('Index')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
threshold = 0.15

# Find indices where value > threshold

# Frame with Anomaly
indices = [i for i, v in enumerate(absolute_error[frame_id_anomaly]) if v > threshold]

# Print results
print("Frame with anomaly")
print("Indices of values > threshold:", indices)
print("Corresponding values:", [absolute_error[frame_id_anomaly][i] for i in indices])


print("-------------------------------------------------------------------------------")


# Normal with Anomaly
indices = [i for i, v in enumerate(absolute_error[frame_id_normal]) if v > threshold]

# Print results
print("Normal frame")
print("Indices of values > threshold:", indices)
print("Corresponding values:", [absolute_error[frame_id_normal][i] for i in indices])
# Out:
# Frame with anomaly
# Indices of values > threshold: [37, 77]
# Corresponding values: [np.float64(0.2641199789333344), np.float64(0.5070183235569)]
# -------------------------------------------------------------------------------
# Normal frame
# Indices of values > threshold: []
# Corresponding values: []

# %% [markdown]
# #### Squared error

# %%
plt.figure(figsize=(12, 4))

plt.plot(squared_error[frame_id_anomaly], label='Frame with anomaly', color='orange')
plt.plot(squared_error[frame_id_normal], label='Normal Frame', color='blue')

plt.title('Squared Error Comparison')
plt.xlabel('Index')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
threshold = 0.015

# Find indices where value > threshold

# Frame with Anomaly
indices = [i for i, v in enumerate(squared_error[frame_id_anomaly]) if v > threshold]

# Print results
print("Frame with anomaly")
print("Indices of values > threshold:", indices)
print("Corresponding values:", [squared_error[frame_id_anomaly][i] for i in indices])


print("-------------------------------------------------------------------------------")


# Normal with Anomaly
indices = [i for i, v in enumerate(squared_error[frame_id_normal]) if v > threshold]

# Print results
print("Normal frame")
print("Indices of values > threshold:", indices)
print("Corresponding values:", [squared_error[frame_id_normal][i] for i in indices])
# Out:
# Frame with anomaly
# Indices of values > threshold: [37, 77]
# Corresponding values: [np.float64(0.069759363271745), np.float64(0.25706758042244937)]
# -------------------------------------------------------------------------------
# Normal frame
# Indices of values > threshold: []
# Corresponding values: []

# %% [markdown]
# ### Focal loss

# %%
def focal_mse_loss(prediction, target, gamma=2.5):
    error = prediction - target
    squared_error = error ** 2
    loss = squared_error ** gamma
    return loss

# %%
# --- Focal Loss Calculation ---
focal_loss = focal_mse_loss(reconstructed, original)  # element-wise focal loss

# Total focal loss per sample (row-wise sum)
focal_loss_per_frame = focal_loss.sum(axis=1)

# %%
plt.figure(figsize=(12, 4))

plt.plot(focal_loss[frame_id_anomaly], label='Frame with anomaly', color='orange')
plt.plot(focal_loss[frame_id_normal], label='Normal Frame', color='blue')

plt.title('Squared Error Comparison')
plt.xlabel('Index')
plt.ylabel('Error')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
threshold = 0.00008

# Find indices where value > threshold

# Frame with Anomaly
indices = [i for i, v in enumerate(focal_loss[frame_id_anomaly]) if v > threshold]

# Print results
print("Frame with anomaly")
print("Indices of values > threshold:", indices)
print("Corresponding values:", [focal_loss[frame_id_anomaly][i] for i in indices])


print("-------------------------------------------------------------------------------")


# Normal with Anomaly
indices = [i for i, v in enumerate(focal_loss[frame_id_normal]) if v > threshold]

# Print results
print("Normal frame")
print("Indices of values > threshold:", indices)
print("Corresponding values:", [focal_loss[frame_id_normal][i] for i in indices])
# Out:
# Frame with anomaly
# Indices of values > threshold: [37, 77]
# Corresponding values: [np.float64(0.0012853052154504576), np.float64(0.033505667527642634)]
# -------------------------------------------------------------------------------
# Normal frame
# Indices of values > threshold: []
# Corresponding values: []

# %% [markdown]
# To do: add reconstruciton on testing dataset
