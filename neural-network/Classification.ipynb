# %% [markdown]
# # Classifier example

# %% [markdown]
# One of the most common uses for neural networks is as a classifier, where input data is mapped to a series of classes, usually as a probability distribution. This is particularly useful if we have access to a number of examples of a particular class, for example a series of images that contain cats and a series of images that do not contain any cats. In this case it is clear to see that defining a closed form expression for whether an image contains a cat would be difficult, thus we wish to implicitly learn the relationship from the data.
#
# In this example, we will construct a network that is looking to classify whether a particular type of anomaly is occurring in our signal of interest. The likelihood of the signal occurring in the dataset will be mapped to a single output, where a higher value indicates a higher likelihood of the anomaly having occurred.

# %%
# import the relevant libraries
import itertools

import matplotlib.pyplot as plt
import numpy as np

from moku.nn import LinnModel, save_linn

# set the seed for repeatability
np.random.seed(42)
# Out:
# 2024-12-10 22:49:42.656177: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733870982.680237   27804 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733870982.686817   27804 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-10 22:49:42.708333: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Data generation

# %% [markdown]
# For this example, we will use the serial input mode of the neural network instrument. This mode corresponds to taking a rolling window of points from a single input channel which are fed into the model as a single input vector. The maximum input size we can take is a vector of length 100, thus, we will generate a series of signals of length 100. The anomaly that we will try to classify will look like a plateau in an otherwise periodic signal with some noise.
#
# We will start by generating a series of clean signals that we will inject random anomalies into.

# %%
# length of the input signal
N = 100

# time series over which to define the signals
T = np.array([t for t in range(N)])

# a range of phases and frequencies to generate signals over
P = [2 * p for p in range(N // 2)]
omega = np.pi / np.array([o for o in range(8, 64)])

# a range of widths for our signal anomaly
dT = np.array([10 + dt for dt in range(22)])

# create all the signals
signals = []
for o, p in list(itertools.product(omega, P)):
    s = np.sin(o * (T + p))
    signals.append(s)

# view some of the signals so we get a sense of what we're generating
plt.figure(figsize=(15, 5))
count_signals = 0
for i in range(0, len(signals), 1000):
    plt.plot(signals[i], label=str('signal ' + str(count_signals)))
    count_signals += 1

plt.xlabel('Sample points')
plt.ylabel('Amplitude (arb.)')
plt.legend()
plt.show()

# %% [markdown]
# Using these signals we will create two classes: defective and non-defective, corresponding to a signal containing an anomaly or no anomaly respectively. We will generate a few examples of each phase and frequency combination we generated earlier with different anomalies and noise. As we are not triggering the acquisition we will assume that the anomaly could occur anywhere in the signal.

# %%
# list to hold all the signals with defect
sigs_dfct = []
for i in range(2):
    # make a copy so we don't modify the original and then shuffle it
    sig1 = np.copy(signals)
    np.random.shuffle(sig1)

    # for each signal in the list, modify it to have an anomaly and noise
    for s in sig1:
        # choose a starting index and width
        start_idx = np.random.choice(T, replace=True)
        dt = np.random.choice(dT, replace=True)

        # clip to the bounds of the array
        if start_idx + dt >= N:
            start_idx = N - dt

        # create an array of indicies that we will modify
        idxs = np.array([start_idx + d for d in range(dt)])
        idxs = idxs[idxs < N]

        # set all the indices to the same value as the anomaly
        s[idxs] = s[start_idx]

        # flip the symmetry of the anomaly on the second iteration
        if i == 1:
            s[idxs] = s[idxs[-1]]

        # create some noise and add it to the signal
        noise = np.random.rand(N) * 0.2
        sigs_dfct.append(s + noise)

# create some non-defective signals with noise
sigs_non = []
for i in range(2):
    # copy the signals to avoid modification
    sig1 = np.copy(signals)
    np.random.shuffle(sig1)

    # add the noise and store them
    for s in sig1:
        noise = np.random.rand(N) * 0.2
        sigs_non.append(s + noise)

# plot an example of what we just created
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
ax[0].plot(sigs_dfct[-1])
ax[0].plot(range(idxs[0], idxs[-1]), sigs_dfct[-1][idxs[0] : idxs[-1]], 'r')
ax[0].legend(['Signal', 'Anomaly'])
ax[0].set_xlabel('Sample points')
ax[0].set_ylabel('Amplitude (arb.)')
ax[0].set_title('Example of Defective signal')

plt.plot(sigs_non[0])
ax[1].legend(['Signal'])
ax[1].set_xlabel('Sample points')
ax[1].set_title('Example of Non-defective signal')
plt.tight_layout()
plt.show()

# %% [markdown]
# We will use these signals now to construct the training data. We need to assign the labels correctly to the different classes where 0 corresponds to non-defective and 1 corresponds to defective. We will also have reserve 10% of the data for validation of the model performance.

# %%
# construct the arrays, we will use half of them
X = np.concatenate([sigs_non[: len(sigs_non) // 2], sigs_dfct[: len(sigs_non) // 2]], axis=0)
y = np.concatenate([np.zeros(len(sigs_non) // 2), np.ones(len(sigs_non) // 2)], axis=0)

# shuffle the arrays to avoid training bias
random_idx = [i for i in range(len(y))]
np.random.shuffle(random_idx)
X = X[random_idx]
y = y[random_idx].reshape(-1, 1)

# get 10% of the random indices for the validation set
data_indices = np.arange(0, len(X), 1)
np.random.shuffle(data_indices)
val_length = int(len(X) * 0.1)
train_indices = data_indices[val_length:]
val_indices = data_indices[:val_length]

# separate the training and validation sets
train_X = X[train_indices]
train_y = y[train_indices]
val_X = X[val_indices]
val_y = y[val_indices]

# %% [markdown]
# # Model definition and training

# %% [markdown]
# Now that we have generated the training data we need to construct our model. As usual we will do this using the provided quantised model class. For this model we will be mapping the 100 length vector input to a single output which has the tanh activation function. The tanh function will act similarly to the the classical sigmoid function, but in this case allows us scale our outputs to the range `[-1, 1]` which is the scaling used by the quantised model. We will also use 4 intermediate layers of reducing size to perform the classification, with each layer having a ReLU activation function.
#
# We will train this model for up to 1000 epochs and configure an early stopping setup to stop when the model training loss plateaus.

# %%
# instantiate the quantised model and set the training data
quant_mod = LinnModel()
quant_mod.set_training_data(training_inputs=train_X, training_outputs=train_y)

# define the model architecture and construct it.
model_definition = [(80, 'relu'), (64, 'relu'), (64, 'relu'), (32, 'relu'), (1,'tanh')]
quant_mod.construct_model(model_definition, show_summary=True, loss='mse')
# Out:
# 2024-12-10 22:49:47.514673: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 80)             │         8,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer               │ (None, 80)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         5,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_1             │ (None, 64)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_2             │ (None, 64)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_3             │ (None, 32)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_4             │ (None, 1)              │             0 │
# │ (OutputClipLayer)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,537 (76.32 KB)
#  Trainable params: 19,537 (76.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Kick off the training
es_config = {'monitor': 'loss', 'patience': 100, 'restore': True}
history = quant_mod.fit_model(epochs=1000, validation_data=(val_X, val_y), es_config=es_config)
# Out:
# Epoch 1/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.9772 - val_loss: 0.4573
# Epoch 2/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7274 - val_loss: 0.3897
# Epoch 3/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5417 - val_loss: 0.5025
# Epoch 4/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4619 - val_loss: 0.4425
# Epoch 5/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4104 - val_loss: 0.5479
# Epoch 6/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3991 - val_loss: 0.4751
# Epoch 7/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3443 - val_loss: 0.5120
# Epoch 8/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3026 - val_loss: 0.5282
# Epoch 9/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2850 - val_loss: 0.4976
# Epoch 10/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2625 - val_loss: 0.5395
# Epoch 11/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2979 - val_loss: 0.5190
# Epoch 12/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2490 - val_loss: 0.5440
# Epoch 13/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2289 - val_loss: 0.5625
# Epoch 14/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2353 - val_loss: 0.5421
# Epoch 15/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2275 - val_loss: 0.5215
# Epoch 16/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2255 - val_loss: 0.4849
# Epoch 17/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2179 - val_loss: 0.5350
# Epoch 18/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2145 - val_loss: 0.5254
# Epoch 19/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1925 - val_loss: 0.4758
# Epoch 20/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2085 - val_loss: 0.4947
# Epoch 21/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1946 - val_loss: 0.5127
# Epoch 22/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1799 - val_loss: 0.5483
# Epoch 23/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1960 - val_loss: 0.5101
# Epoch 24/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1736 - val_loss: 0.5290
# Epoch 25/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1811 - val_loss: 0.5198
# Epoch 26/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1822 - val_loss: 0.5358
# Epoch 27/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1475 - val_loss: 0.5284
# Epoch 28/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1870 - val_loss: 0.5336
# Epoch 29/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1709 - val_loss: 0.5447
# Epoch 30/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1751 - val_loss: 0.4913
# Epoch 31/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1581 - val_loss: 0.5207
# Epoch 32/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1655 - val_loss: 0.5186
# Epoch 33/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2126 - val_loss: 0.5273
# Epoch 34/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1618 - val_loss: 0.5764
# Epoch 35/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1574 - val_loss: 0.5392
# Epoch 36/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1688 - val_loss: 0.5375
# Epoch 37/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1486 - val_loss: 0.5133
# Epoch 38/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1260 - val_loss: 0.5424
# Epoch 39/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1513 - val_loss: 0.5226
# Epoch 40/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1226 - val_loss: 0.5234
# Epoch 41/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1473 - val_loss: 0.5323
# Epoch 42/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1452 - val_loss: 0.5425
# Epoch 43/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1201 - val_loss: 0.5561
# Epoch 44/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1451 - val_loss: 0.5119
# Epoch 45/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1112 - val_loss: 0.4992
# Epoch 46/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1387 - val_loss: 0.5262
# Epoch 47/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1292 - val_loss: 0.5287
# Epoch 48/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1423 - val_loss: 0.5152
# Epoch 49/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1183 - val_loss: 0.5297
# Epoch 50/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1263 - val_loss: 0.4964
# Epoch 51/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1444 - val_loss: 0.5434
# Epoch 52/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1416 - val_loss: 0.5059
# Epoch 53/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1391 - val_loss: 0.5384
# Epoch 54/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1382 - val_loss: 0.5027
# Epoch 55/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1238 - val_loss: 0.5324
# Epoch 56/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1246 - val_loss: 0.5233
# Epoch 57/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1237 - val_loss: 0.4937
# Epoch 58/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1116 - val_loss: 0.5630
# Epoch 59/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1195 - val_loss: 0.5351
# Epoch 60/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1193 - val_loss: 0.4958
# Epoch 61/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1312 - val_loss: 0.4902
# Epoch 62/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1107 - val_loss: 0.5200
# Epoch 63/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1223 - val_loss: 0.4758
# Epoch 64/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1138 - val_loss: 0.5155
# Epoch 65/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1274 - val_loss: 0.5061
# Epoch 66/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1073 - val_loss: 0.5124
# Epoch 67/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1264 - val_loss: 0.5059
# Epoch 68/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1180 - val_loss: 0.5339
# Epoch 69/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0899 - val_loss: 0.5205
# Epoch 70/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1186 - val_loss: 0.4808
# Epoch 71/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1299 - val_loss: 0.5508
# Epoch 72/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1165 - val_loss: 0.5239
# Epoch 73/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1004 - val_loss: 0.5481
# Epoch 74/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1066 - val_loss: 0.4924
# Epoch 75/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1182 - val_loss: 0.5264
# Epoch 76/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1131 - val_loss: 0.5106
# Epoch 77/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1250 - val_loss: 0.4997
# Epoch 78/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1183 - val_loss: 0.5236
# Epoch 79/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1143 - val_loss: 0.5220
# Epoch 80/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1166 - val_loss: 0.5452
# Epoch 81/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1176 - val_loss: 0.5130
# Epoch 82/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1077 - val_loss: 0.5453
# Epoch 83/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1055 - val_loss: 0.5165
# Epoch 84/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0949 - val_loss: 0.5327
# Epoch 85/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1041 - val_loss: 0.5186
# Epoch 86/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0926 - val_loss: 0.5254
# Epoch 87/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1080 - val_loss: 0.5102
# Epoch 88/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0927 - val_loss: 0.5635
# Epoch 89/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0911 - val_loss: 0.5130
# Epoch 90/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1056 - val_loss: 0.5386
# Epoch 91/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0952 - val_loss: 0.5372
# Epoch 92/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0936 - val_loss: 0.5367
# Epoch 93/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0881 - val_loss: 0.5251
# Epoch 94/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1133 - val_loss: 0.5312
# Epoch 95/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0957 - val_loss: 0.5655
# Epoch 96/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1019 - val_loss: 0.5050
# Epoch 97/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0991 - val_loss: 0.5570
# Epoch 98/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0977 - val_loss: 0.5317
# Epoch 99/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0915 - val_loss: 0.5560
# Epoch 100/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1040 - val_loss: 0.5396
# Epoch 101/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0898 - val_loss: 0.5438
# Epoch 102/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1173 - val_loss: 0.5363
# Epoch 103/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0943 - val_loss: 0.5113
# Epoch 104/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0633 - val_loss: 0.5390
# Epoch 105/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0921 - val_loss: 0.5500
# Epoch 106/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0948 - val_loss: 0.5707
# Epoch 107/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0882 - val_loss: 0.5430
# Epoch 108/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0849 - val_loss: 0.5392
# Epoch 109/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0824 - val_loss: 0.5157
# Epoch 110/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0937 - val_loss: 0.5293
# Epoch 111/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0852 - val_loss: 0.5725
# Epoch 112/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0988 - val_loss: 0.5414
# Epoch 113/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0987 - val_loss: 0.5374
# Epoch 114/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0905 - val_loss: 0.5583
# Epoch 115/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1315 - val_loss: 0.5343
# Epoch 116/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0930 - val_loss: 0.5644
# Epoch 117/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0656 - val_loss: 0.5427
# Epoch 118/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0785 - val_loss: 0.5199
# Epoch 119/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0901 - val_loss: 0.5430
# Epoch 120/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0738 - val_loss: 0.5464
# Epoch 121/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0843 - val_loss: 0.5372
# Epoch 122/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0919 - val_loss: 0.5063
# Epoch 123/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0785 - val_loss: 0.5111
# Epoch 124/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0747 - val_loss: 0.5568
# Epoch 125/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0831 - val_loss: 0.5530
# Epoch 126/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0933 - val_loss: 0.5849
# Epoch 127/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1126 - val_loss: 0.5802
# Epoch 128/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0970 - val_loss: 0.5169
# Epoch 129/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0927 - val_loss: 0.5390
# Epoch 130/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0738 - val_loss: 0.5351
# Epoch 131/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0585 - val_loss: 0.5662
# Epoch 132/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0758 - val_loss: 0.5502
# Epoch 133/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0670 - val_loss: 0.5253
# Epoch 134/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0811 - val_loss: 0.5317
# Epoch 135/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0659 - val_loss: 0.5371
# Epoch 136/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0785 - val_loss: 0.5423
# Epoch 137/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0615 - val_loss: 0.5479
# Epoch 138/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0771 - val_loss: 0.5597
# Epoch 139/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0816 - val_loss: 0.5265
# Epoch 140/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0623 - val_loss: 0.5605
# Epoch 141/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0764 - val_loss: 0.5558
# Epoch 142/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0616 - val_loss: 0.5568
# Epoch 143/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1271 - val_loss: 0.5368
# Epoch 144/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0922 - val_loss: 0.5441
# Epoch 145/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1057 - val_loss: 0.5758
# Epoch 146/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0693 - val_loss: 0.5574
# Epoch 147/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0998 - val_loss: 0.5622
# Epoch 148/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1223 - val_loss: 0.5634
# Epoch 149/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0778 - val_loss: 0.5568
# Epoch 150/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0818 - val_loss: 0.5433
# Epoch 151/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0620 - val_loss: 0.5662
# Epoch 152/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0608 - val_loss: 0.5402
# Epoch 153/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0769 - val_loss: 0.5458
# Epoch 154/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0862 - val_loss: 0.5236
# Epoch 155/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0691 - val_loss: 0.5401
# Epoch 156/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0624 - val_loss: 0.5415
# Epoch 157/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0772 - val_loss: 0.5361
# Epoch 158/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0577 - val_loss: 0.5260
# Epoch 159/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0859 - val_loss: 0.5389
# Epoch 160/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0550 - val_loss: 0.5606
# Epoch 161/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0617 - val_loss: 0.5552
# Epoch 162/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0577 - val_loss: 0.5415
# Epoch 163/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0704 - val_loss: 0.5539
# Epoch 164/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0682 - val_loss: 0.5634
# Epoch 165/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0643 - val_loss: 0.5603
# Epoch 166/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0741 - val_loss: 0.5493
# Epoch 167/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0743 - val_loss: 0.5156
# Epoch 168/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0802 - val_loss: 0.5156
# Epoch 169/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0716 - val_loss: 0.5365
# Epoch 170/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0748 - val_loss: 0.5436
# Epoch 171/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0692 - val_loss: 0.5508
# Epoch 172/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0716 - val_loss: 0.5162
# Epoch 173/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0675 - val_loss: 0.5387
# Epoch 174/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0771 - val_loss: 0.5062
# Epoch 175/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0581 - val_loss: 0.5325
# Epoch 176/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0660 - val_loss: 0.5317
# Epoch 177/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0615 - val_loss: 0.5545
# Epoch 178/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0546 - val_loss: 0.5471
# Epoch 179/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0725 - val_loss: 0.5430
# Epoch 180/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0674 - val_loss: 0.5389
# Epoch 181/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0662 - val_loss: 0.5408
# Epoch 182/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0593 - val_loss: 0.5517
# Epoch 183/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0673 - val_loss: 0.5790
# Epoch 184/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0844 - val_loss: 0.5184
# Epoch 185/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0482 - val_loss: 0.5305
# Epoch 186/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0625 - val_loss: 0.5281
# Epoch 187/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0528 - val_loss: 0.5401
# Epoch 188/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0594 - val_loss: 0.5463
# Epoch 189/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0588 - val_loss: 0.5293
# Epoch 190/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0647 - val_loss: 0.4925
# Epoch 191/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0556 - val_loss: 0.5427
# Epoch 192/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0775 - val_loss: 0.5351
# Epoch 193/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0544 - val_loss: 0.5049
# Epoch 194/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0494 - val_loss: 0.5669
# Epoch 195/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0664 - val_loss: 0.5459
# Epoch 196/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0583 - val_loss: 0.5451
# Epoch 197/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0833 - val_loss: 0.5476
# Epoch 198/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0644 - val_loss: 0.5232
# Epoch 199/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0566 - val_loss: 0.5184
# Epoch 200/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0874 - val_loss: 0.5328
# Epoch 201/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0622 - val_loss: 0.5427
# Epoch 202/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0689 - val_loss: 0.5720
# Epoch 203/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1212 - val_loss: 0.5166
# Epoch 204/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0538 - val_loss: 0.5606
# Epoch 205/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0655 - val_loss: 0.5552
# Epoch 206/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0488 - val_loss: 0.5628
# Epoch 207/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0796 - val_loss: 0.5442
# Epoch 208/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0710 - val_loss: 0.5686
# Epoch 209/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0652 - val_loss: 0.5257
# Epoch 210/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0595 - val_loss: 0.5752
# Epoch 211/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0675 - val_loss: 0.5427
# Epoch 212/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0518 - val_loss: 0.5196
# Epoch 213/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0590 - val_loss: 0.5159
# Epoch 214/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0554 - val_loss: 0.5144
# Epoch 215/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0668 - val_loss: 0.5453
# Epoch 216/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0509 - val_loss: 0.5432
# Epoch 217/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0612 - val_loss: 0.5386
# Epoch 218/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0474 - val_loss: 0.5451
# Epoch 219/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0952 - val_loss: 0.5570
# Epoch 220/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0484 - val_loss: 0.5848
# Epoch 221/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0575 - val_loss: 0.5512
# Epoch 222/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0559 - val_loss: 0.5344
# Epoch 223/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0472 - val_loss: 0.5479
# Epoch 224/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0739 - val_loss: 0.5265
# Epoch 225/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0494 - val_loss: 0.5505
# Epoch 226/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0483 - val_loss: 0.5295
# Epoch 227/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0445 - val_loss: 0.5468
# Epoch 228/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0737 - val_loss: 0.5359
# Epoch 229/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0542 - val_loss: 0.5287
# Epoch 230/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0494 - val_loss: 0.5539
# Epoch 231/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0588 - val_loss: 0.5511
# Epoch 232/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0542 - val_loss: 0.5794
# Epoch 233/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0532 - val_loss: 0.5697
# Epoch 234/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0413 - val_loss: 0.5343
# Epoch 235/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0656 - val_loss: 0.5720
# Epoch 236/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0613 - val_loss: 0.5350
# Epoch 237/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0420 - val_loss: 0.5274
# Epoch 238/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0537 - val_loss: 0.5527
# Epoch 239/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0551 - val_loss: 0.5441
# Epoch 240/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0498 - val_loss: 0.5484
# Epoch 241/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0570 - val_loss: 0.5418
# Epoch 242/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0493 - val_loss: 0.5517
# Epoch 243/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0645 - val_loss: 0.5280
# Epoch 244/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0636 - val_loss: 0.5652
# Epoch 245/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0607 - val_loss: 0.5483
# Epoch 246/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0488 - val_loss: 0.5419
# Epoch 247/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0514 - val_loss: 0.5167
# Epoch 248/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0570 - val_loss: 0.5405
# Epoch 249/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0575 - val_loss: 0.5263
# Epoch 250/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0536 - val_loss: 0.5368
# Epoch 251/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0610 - val_loss: 0.5191
# Epoch 252/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0341 - val_loss: 0.6102
# Epoch 253/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0730 - val_loss: 0.5373
# Epoch 254/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0703 - val_loss: 0.5580
# Epoch 255/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0652 - val_loss: 0.5675
# Epoch 256/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0387 - val_loss: 0.5492
# Epoch 257/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0605 - val_loss: 0.5644
# Epoch 258/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0877 - val_loss: 0.5534
# Epoch 259/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0457 - val_loss: 0.5531
# Epoch 260/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0422 - val_loss: 0.5513
# Epoch 261/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0507 - val_loss: 0.5508
# Epoch 262/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0565 - val_loss: 0.5274
# Epoch 263/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0414 - val_loss: 0.5608
# Epoch 264/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0457 - val_loss: 0.5319
# Epoch 265/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0486 - val_loss: 0.5409
# Epoch 266/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0499 - val_loss: 0.5428
# Epoch 267/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462 - val_loss: 0.5310
# Epoch 268/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0412 - val_loss: 0.5402
# Epoch 269/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0377 - val_loss: 0.5833
# Epoch 270/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0697 - val_loss: 0.5475
# Epoch 271/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0603 - val_loss: 0.5525
# Epoch 272/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0486 - val_loss: 0.5443
# Epoch 273/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0506 - val_loss: 0.5514
# Epoch 274/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0387 - val_loss: 0.5490
# Epoch 275/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0442 - val_loss: 0.5558
# Epoch 276/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0286 - val_loss: 0.5646
# Epoch 277/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0363 - val_loss: 0.5794
# Epoch 278/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0675 - val_loss: 0.5314
# Epoch 279/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0505 - val_loss: 0.5581
# Epoch 280/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0619 - val_loss: 0.5550
# Epoch 281/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0593 - val_loss: 0.5294
# Epoch 282/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0521 - val_loss: 0.5321
# Epoch 283/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0544 - val_loss: 0.5295
# Epoch 284/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0324 - val_loss: 0.5572
# Epoch 285/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0301 - val_loss: 0.5209
# Epoch 286/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0413 - val_loss: 0.5552
# Epoch 287/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0531 - val_loss: 0.5484
# Epoch 288/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0673 - val_loss: 0.5365
# Epoch 289/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0535 - val_loss: 0.5790
# Epoch 290/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0789 - val_loss: 0.5405
# Epoch 291/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0467 - val_loss: 0.5243
# Epoch 292/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0580 - val_loss: 0.5630
# Epoch 293/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0445 - val_loss: 0.5563
# Epoch 294/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0540 - val_loss: 0.5510
# Epoch 295/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0641 - val_loss: 0.5301
# Epoch 296/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0472 - val_loss: 0.5468
# Epoch 297/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0459 - val_loss: 0.5678
# Epoch 298/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0360 - val_loss: 0.5740
# Epoch 299/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0304 - val_loss: 0.5558
# Epoch 300/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0564 - val_loss: 0.5385
# Epoch 301/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0437 - val_loss: 0.5230
# Epoch 302/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0587 - val_loss: 0.5492
# Epoch 303/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0321 - val_loss: 0.5736
# Epoch 304/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0660 - val_loss: 0.5184
# Epoch 305/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0558 - val_loss: 0.5675
# Epoch 306/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0253 - val_loss: 0.5487
# Epoch 307/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0576 - val_loss: 0.5478
# Epoch 308/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0645 - val_loss: 0.5219
# Epoch 309/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0700 - val_loss: 0.5261
# Epoch 310/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0417 - val_loss: 0.5686
# Epoch 311/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0530 - val_loss: 0.5482
# Epoch 312/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0572 - val_loss: 0.5818
# Epoch 313/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0529 - val_loss: 0.5668
# Epoch 314/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0404 - val_loss: 0.5347
# Epoch 315/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0498 - val_loss: 0.5352
# Epoch 316/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0316 - val_loss: 0.5683
# Epoch 317/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0326 - val_loss: 0.5515
# Epoch 318/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0399 - val_loss: 0.5446
# Epoch 319/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0583 - val_loss: 0.5485
# Epoch 320/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0441 - val_loss: 0.5561
# Epoch 321/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0393 - val_loss: 0.5407
# Epoch 322/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0741 - val_loss: 0.5621
# Epoch 323/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0328 - val_loss: 0.5413
# Epoch 324/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0247 - val_loss: 0.5692
# Epoch 325/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0467 - val_loss: 0.5457
# Epoch 326/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0632 - val_loss: 0.5672
# Epoch 327/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0398 - val_loss: 0.5755
# Epoch 328/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0380 - val_loss: 0.5544
# Epoch 329/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0196 - val_loss: 0.5801
# Epoch 330/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0558 - val_loss: 0.5460
# Epoch 331/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0359 - val_loss: 0.5804
# Epoch 332/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0772 - val_loss: 0.5963
# Epoch 333/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0326 - val_loss: 0.5837
# Epoch 334/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0532 - val_loss: 0.5730
# Epoch 335/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0413 - val_loss: 0.5477
# Epoch 336/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0475 - val_loss: 0.5533
# Epoch 337/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0433 - val_loss: 0.5643
# Epoch 338/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0448 - val_loss: 0.5546
# Epoch 339/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0565 - val_loss: 0.5833
# Epoch 340/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0583 - val_loss: 0.5688
# Epoch 341/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0346 - val_loss: 0.5430
# Epoch 342/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0421 - val_loss: 0.5311
# Epoch 343/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0322 - val_loss: 0.5157
# Epoch 344/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0305 - val_loss: 0.5630
# Epoch 345/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0218 - val_loss: 0.5583
# Epoch 346/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0418 - val_loss: 0.5899
# Epoch 347/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0549 - val_loss: 0.5283
# Epoch 348/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0615 - val_loss: 0.5376
# Epoch 349/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0455 - val_loss: 0.5464
# Epoch 350/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0467 - val_loss: 0.5750
# Epoch 351/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0533 - val_loss: 0.5509
# Epoch 352/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - val_loss: 0.5909
# Epoch 353/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0634 - val_loss: 0.5711
# Epoch 354/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0574 - val_loss: 0.5445
# Epoch 355/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - val_loss: 0.5687
# Epoch 356/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466 - val_loss: 0.5671
# Epoch 357/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0366 - val_loss: 0.5847
# Epoch 358/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0234 - val_loss: 0.5685
# Epoch 359/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0364 - val_loss: 0.5952
# Epoch 360/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0619 - val_loss: 0.5529
# Epoch 361/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0602 - val_loss: 0.5690
# Epoch 362/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0412 - val_loss: 0.5802
# Epoch 363/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0434 - val_loss: 0.5555
# Epoch 364/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0776 - val_loss: 0.5664
# Epoch 365/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - val_loss: 0.5739
# Epoch 366/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0363 - val_loss: 0.5791
# Epoch 367/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0301 - val_loss: 0.5607
# Epoch 368/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0330 - val_loss: 0.5786
# Epoch 369/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0628 - val_loss: 0.5744
# Epoch 370/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0453 - val_loss: 0.5913
# Epoch 371/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0385 - val_loss: 0.5877
# Epoch 372/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0584 - val_loss: 0.5883
# Epoch 373/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0679 - val_loss: 0.5577
# Epoch 374/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0740 - val_loss: 0.5451
# Epoch 375/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0347 - val_loss: 0.5532
# Epoch 376/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0324 - val_loss: 0.5388
# Epoch 377/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0453 - val_loss: 0.5594
# Epoch 378/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0398 - val_loss: 0.5516
# Epoch 379/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0225 - val_loss: 0.5395
# Epoch 380/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0303 - val_loss: 0.5759
# Epoch 381/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0471 - val_loss: 0.5551
# Epoch 382/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0497 - val_loss: 0.5508
# Epoch 383/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0360 - val_loss: 0.5297
# Epoch 384/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0323 - val_loss: 0.5484
# Epoch 385/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0426 - val_loss: 0.5812
# Epoch 386/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0373 - val_loss: 0.5740
# Epoch 387/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0571 - val_loss: 0.5686
# Epoch 388/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0442 - val_loss: 0.5821
# Epoch 389/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0347 - val_loss: 0.5802
# Epoch 390/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0264 - val_loss: 0.5925
# Epoch 391/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0594 - val_loss: 0.5539
# Epoch 392/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0277 - val_loss: 0.5651
# Epoch 393/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0463 - val_loss: 0.5768
# Epoch 394/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0303 - val_loss: 0.5839
# Epoch 395/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0382 - val_loss: 0.5763
# Epoch 396/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0394 - val_loss: 0.5621
# Epoch 397/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0236 - val_loss: 0.5847
# Epoch 398/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0514 - val_loss: 0.5982
# Epoch 399/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0621 - val_loss: 0.5620
# Epoch 400/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0472 - val_loss: 0.5653
# Epoch 401/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0289 - val_loss: 0.5996
# Epoch 402/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0446 - val_loss: 0.5812
# Epoch 403/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0291 - val_loss: 0.5651
# Epoch 404/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0640 - val_loss: 0.5686
# Epoch 405/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0218 - val_loss: 0.5840
# Epoch 406/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0349 - val_loss: 0.5679
# Epoch 407/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0390 - val_loss: 0.5572
# Epoch 408/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0518 - val_loss: 0.5399
# Epoch 409/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0328 - val_loss: 0.5607
# Epoch 410/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0289 - val_loss: 0.5660
# Epoch 411/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0194 - val_loss: 0.5794
# Epoch 412/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0497 - val_loss: 0.5428
# Epoch 413/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0456 - val_loss: 0.5527
# Epoch 414/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0224 - val_loss: 0.5542
# Epoch 415/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0269 - val_loss: 0.5952
# Epoch 416/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0756 - val_loss: 0.5437
# Epoch 417/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0377 - val_loss: 0.5329
# Epoch 418/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0386 - val_loss: 0.5401
# Epoch 419/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0341 - val_loss: 0.5582
# Epoch 420/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - val_loss: 0.5619
# Epoch 421/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0549 - val_loss: 0.5608
# Epoch 422/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0363 - val_loss: 0.5423
# Epoch 423/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0408 - val_loss: 0.5835
# Epoch 424/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0558 - val_loss: 0.5857
# Epoch 425/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0380 - val_loss: 0.5647
# Epoch 426/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0244 - val_loss: 0.5657
# Epoch 427/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0340 - val_loss: 0.5773
# Epoch 428/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0299 - val_loss: 0.5831
# Epoch 429/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0275 - val_loss: 0.5910

# %% [markdown]
# We can view the training losses to determine whether the model is performing as expected.

# %%
# Plot the relevant losses
plt.semilogy(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.xlabel('Epochs')
plt.show()

# %% [markdown]
# We can view the accuracy of the model by rounding the predictions to effectively threshold a binary outcome around 0.5. To see the actual distribution of the the outputs plot a distribution of the outputs for both the training and validation predictions.

# %%
def get_accuracy(y_true, y_pred):
    # round up/down to get a binary prediction. This could be modified with different thresholds
    rounded_y_pred = np.round(y_pred)

    # find the accuracy py finding when the difference is 0
    diff = y_true - rounded_y_pred
    return np.array(diff == 0, dtype=int).sum() / len(diff)

# %%
# get the training predictions
preds = quant_mod.predict(train_X)
y_train_acc = get_accuracy(train_y, preds) * 100

# get the validation predictions
preds_val = quant_mod.predict(val_X)
y_val_acc = get_accuracy(val_y, preds_val) * 100

print(
    '-' * 10
    + ' Model Accuracy '
    + '-' * 10
    + '\nTrain: \t %.2f %%' % y_train_acc
    + '\nVal: \t %.2f %%\n' % y_val_acc
    + '-' * 36
)
# Out:
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ---------- Model Accuracy ----------
# Train: 	 91.96 %
# Val: 	 91.61 %
# ------------------------------------

# %%
# plot a histogram of all the predictions
plt.hist(preds, bins=np.linspace(0, 1, 101), label='prediction on training dataset')
plt.hist(preds_val, bins=np.linspace(0, 1, 101), label='prediction on validation dataset')
plt.ylabel('Counts')
plt.xlabel('Output value')
plt.legend()
plt.show()

# %% [markdown]
# Test the model on unseen data (data not used in training).
#
# As the training and validation sets were created using half of the datapoints generated at the beginning of the script, we'll use the second half to test the model on unseen dat.

# %%
# construct the arrays, we will use the second half of the original signals
X_test = np.concatenate([sigs_non[len(sigs_non) // 2 :], sigs_dfct[len(sigs_non) // 2 :]], axis=0)
y_test = np.concatenate([np.zeros(len(sigs_non) // 2), np.ones(len(sigs_non) // 2)], axis=0)

# shuffle the arrays to avoid training bias
random_idx_test = [i for i in range(len(y_test))]
np.random.shuffle(random_idx_test)
X_test = X_test[random_idx_test]
y_test = y_test[random_idx_test].reshape(-1, 1)

# %%
# get the training predictions
preds_test = quant_mod.predict(X_test)
y_test_acc = get_accuracy(y_test, preds_test) * 100

print('-' * 10 + ' Model Accuracy ' + '-' * 10 + '\nTrain: \t %.2f %%' % y_test_acc)

# plot a histogram of all the predictions
plt.hist(preds_test, bins=np.linspace(0, 1, 101))
plt.ylabel('Counts')
plt.xlabel('Output value')
plt.show()
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ---------- Model Accuracy ----------
# Train: 	 91.80 %

# %%
save_linn(quant_mod, input_channels=1, output_channels=1, file_name='classifier.linn')
# Out:
# Skipping layer 0 with type <class 'keras.src.layers.core.input_layer.InputLayer'>
# Skipping layer 2 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 4 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 6 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 8 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 10 with type <class 'moku.nn._linn.OutputClipLayer'>
# Network latency approx. 355 cycles
