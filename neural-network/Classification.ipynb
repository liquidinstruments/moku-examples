# %% [markdown]
# # Classifier example

# %% [markdown]
# One of the most common uses for neural networks is as a classifier, where input data is mapped to a series of classes, usually as a probability distribution. This is particularly useful if we have access to a number of examples of a particular class, for example a series of images that contain cats and a series of images that do not contain any cats. In this case it is clear to see that defining a closed form expression for whether an image contains a cat would be difficult, thus we wish to implicitly learn the relationship from the data.
#
# In this example, we will construct a network that is looking to classify whether a particular type of anomaly is occurring in our signal of interest. The likelihood of the signal occurring in the dataset will be mapped to a single output, where a higher value indicates a higher likelihood of the anomaly having occurred.

# %%
# import the relevant libraries
import itertools

import matplotlib.pyplot as plt
import numpy as np

from moku.nn import LinnModel, save_linn

# set the seed for repeatability
np.random.seed(42)

# %% [markdown]
# # Data generation

# %% [markdown]
# For this example, we will use the serial input mode of the neural network instrument. This mode corresponds to taking a rolling window of points from a single input channel which are fed into the model as a single input vector. The maximum input size we can take is a vector of length 100, thus, we will generate a series of signals of length 100. The anomaly that we will try to classify will look like a plateau in an otherwise periodic signal with some noise.
#
# We will start by generating a series of clean signals that we will inject random anomalies into.

# %%
# length of the input signal
N = 100

# time series over which to define the signals
T = np.array([t for t in range(N)])

# a range of phases and frequencies to generate signals over
P = [2 * p for p in range(N // 2)]
OO = np.pi / np.array([o for o in range(8, 64)])

# a range of widths for our signal anomaly
dT = np.array([10 + dt for dt in range(22)])

# create all the signals
signals = []
for o, p in list(itertools.product(OO, P)):
    s = np.sin(o * (T + p))
    signals.append(s)

# view some of the signals so we get a sense of what we're generating
plt.figure(figsize=(15, 5))
count_signals = 0
for i in range(0, len(signals), 1000):
    plt.plot(signals[i], label=str('signal ' + str(count_signals)))
    count_signals += 1

plt.xlabel('Sample points')
plt.ylabel('Amplitude (arb.)')
plt.legend()
plt.show()

# %% [markdown]
# Using these signals we will create two classes: defective and non-defective, corresponding to a signal containing an anomaly or no anomaly respectively. We will generate a few examples of each phase and frequency combination we generated earlier with different anomalies and noise. As we are not triggering the acquisition we will assume that the anomaly could occur anywhere in the signal.

# %%
# list to hold all the signals with defect
sigs_dfct = []
for i in range(2):
    # make a copy so we don't modify the original and then shuffle it
    sig1 = np.copy(signals)
    np.random.shuffle(sig1)

    # for each signal in the list, modify it to have an anomaly and noise
    for s in sig1:
        # choose a starting index and width
        start_idx = np.random.choice(T, replace=True)
        dt = np.random.choice(dT, replace=True)

        # clip to the bounds of the array
        if start_idx + dt >= N:
            start_idx = N - dt

        # create an array of indicies that we will modify
        idxs = np.array([start_idx + d for d in range(dt)])
        idxs = idxs[idxs < N]

        # set all the indices to the same value as the anomaly
        s[idxs] = s[start_idx]

        # flip the symmetry of the anomaly on the second iteration
        if i == 1:
            s[idxs] = s[idxs[-1]]

        # create some noise and add it to the signal
        noise = np.random.rand(N) * 0.2
        sigs_dfct.append(s + noise)

# create some non-defective signals with noise
sigs_non = []
for i in range(2):
    # copy the signals to avoid modification
    sig1 = np.copy(signals)
    np.random.shuffle(sig1)

    # add the noise and store them
    for s in sig1:
        noise = np.random.rand(N) * 0.2
        sigs_non.append(s + noise)

# plot an example of what we just created
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
ax[0].plot(sigs_dfct[-1])
ax[0].plot(range(idxs[0], idxs[-1]), sigs_dfct[-1][idxs[0] : idxs[-1]], 'r')
ax[0].legend(['Signal', 'Anomaly'])
ax[0].set_xlabel('Sample points')
ax[0].set_ylabel('Amplitude (arb.)')
ax[0].set_title('Example of Defective signal')

plt.plot(sigs_non[0])
ax[1].legend(['Signal'])
ax[1].set_xlabel('Sample points')
ax[1].set_title('Example of Non-defective signal')
plt.tight_layout()
plt.show()

# %% [markdown]
# We will use these signals now to construct the training data. We need to assign the labels correctly to the different classes where 0 corresponds to non-defective and 1 corresponds to defective. We will also have reserve 10% of the data for validation of the model performance.

# %%
# construct the arrays, we will use half of them
X = np.concatenate([sigs_non[: len(sigs_non) // 2], sigs_dfct[: len(sigs_non) // 2]], axis=0)
y = np.concatenate([np.zeros(len(sigs_non) // 2), np.ones(len(sigs_non) // 2)], axis=0)

# shuffle the arrays to avoid training bias
random_idx = [i for i in range(len(y))]
np.random.shuffle(random_idx)
X = X[random_idx]
y = y[random_idx].reshape(-1, 1)

# get 10% of the random indices for the validation set
data_indices = np.arange(0, len(X), 1)
np.random.shuffle(data_indices)
val_length = int(len(X) * 0.1)
train_indices = data_indices[val_length:]
val_indices = data_indices[:val_length]

# separate the training and validation sets
train_X = X[train_indices]
train_y = y[train_indices]
val_X = X[val_indices]
val_y = y[val_indices]

# %% [markdown]
# # Model definition and training

# %% [markdown]
# Now that we have generated the training data we need to construct our model. As usual we will do this using the provided quantised model class. For this model we will be mapping the 100 length vector input to a single output which has the tanh activation function. The tanh function will act similarly to the the classical sigmoid function, but in this case allows us scale our outputs to the range `[-1, 1]` which is the scaling used by the quantised model. We will also use 4 intermediate layers of reducing size to perform the classification, with each layer having a ReLU activation function.
#
# We will train this model for up to 1000 epochs and configure an early stopping setup to stop when the model training loss plateaus.

# %%
# instantiate the quantised model and set the training data
quant_mod = LinnModel()
quant_mod.set_training_data(training_inputs=train_X, training_outputs=train_y)

# define the model architecture and construct it.
model_definition = [(80, 'relu'), (64, 'relu'), (64, 'relu'), (32, 'relu'), (1, 'tanh')]
quant_mod.construct_model(model_definition, show_summary=True, loss='mse')
# Out:
# WARNING:tensorflow:From c:\Users\indir\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 80)             │         8,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer               │ (None, 80)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         5,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_1             │ (None, 64)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_2             │ (None, 64)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_3             │ (None, 32)             │             0 │
# │ (OutputClipLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_clip_layer_4             │ (None, 1)              │             0 │
# │ (OutputClipLayer)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,537 (76.32 KB)
#  Trainable params: 19,537 (76.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Kick off the training
es_config = {'monitor': 'loss', 'patience': 100, 'restore': True}
history = quant_mod.fit_model(epochs=1000, validation_data=(val_X, val_y), es_config=es_config)
# Out:
# Epoch 1/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.9437 - val_loss: 0.3946
# Epoch 2/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6927 - val_loss: 0.3274
# Epoch 3/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5323 - val_loss: 0.3295
# Epoch 4/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4516 - val_loss: 0.3718
# Epoch 5/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3932 - val_loss: 0.3913
# Epoch 6/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3526 - val_loss: 0.4201
# Epoch 7/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3124 - val_loss: 0.4334
# Epoch 8/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2824 - val_loss: 0.4723
# Epoch 9/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2761 - val_loss: 0.4604
# Epoch 10/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2728 - val_loss: 0.4143
# Epoch 11/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2551 - val_loss: 0.4476
# Epoch 12/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2383 - val_loss: 0.4943
# Epoch 13/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2325 - val_loss: 0.4509
# Epoch 14/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2050 - val_loss: 0.5063
# Epoch 15/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2329 - val_loss: 0.4759
# Epoch 16/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2175 - val_loss: 0.4628
# Epoch 17/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2010 - val_loss: 0.4907
# Epoch 18/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1886 - val_loss: 0.4787
# Epoch 19/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2050 - val_loss: 0.4800
# Epoch 20/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2012 - val_loss: 0.5163
# Epoch 21/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1824 - val_loss: 0.5132
# Epoch 22/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1815 - val_loss: 0.5198
# Epoch 23/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1863 - val_loss: 0.4923
# Epoch 24/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1835 - val_loss: 0.4861
# Epoch 25/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1818 - val_loss: 0.4913
# Epoch 26/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1632 - val_loss: 0.4938
# Epoch 27/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1562 - val_loss: 0.4857
# Epoch 28/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1785 - val_loss: 0.4869
# Epoch 29/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1631 - val_loss: 0.4965
# Epoch 30/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1774 - val_loss: 0.5159
# Epoch 31/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1575 - val_loss: 0.4951
# Epoch 32/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1636 - val_loss: 0.4889
# Epoch 33/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1744 - val_loss: 0.5037
# Epoch 34/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1556 - val_loss: 0.4747
# Epoch 35/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1587 - val_loss: 0.4895
# Epoch 36/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1577 - val_loss: 0.5040
# Epoch 37/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1470 - val_loss: 0.4965
# Epoch 38/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1607 - val_loss: 0.4918
# Epoch 39/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1421 - val_loss: 0.4924
# Epoch 40/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1381 - val_loss: 0.4957
# Epoch 41/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1442 - val_loss: 0.5000
# Epoch 42/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1357 - val_loss: 0.4878
# Epoch 43/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1387 - val_loss: 0.5019
# Epoch 44/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1304 - val_loss: 0.5080
# Epoch 45/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1449 - val_loss: 0.4631
# Epoch 46/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1487 - val_loss: 0.5027
# Epoch 47/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1304 - val_loss: 0.4868
# Epoch 48/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1363 - val_loss: 0.4857
# Epoch 49/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1229 - val_loss: 0.4754
# Epoch 50/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1175 - val_loss: 0.5039
# Epoch 51/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1266 - val_loss: 0.5025
# Epoch 52/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1359 - val_loss: 0.4919
# Epoch 53/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1199 - val_loss: 0.4915
# Epoch 54/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1358 - val_loss: 0.4756
# Epoch 55/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1317 - val_loss: 0.4871
# Epoch 56/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1344 - val_loss: 0.4712
# Epoch 57/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1325 - val_loss: 0.4546
# Epoch 58/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1138 - val_loss: 0.4929
# Epoch 59/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1100 - val_loss: 0.4678
# Epoch 60/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1177 - val_loss: 0.4950
# Epoch 61/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1234 - val_loss: 0.4887
# Epoch 62/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1243 - val_loss: 0.4959
# Epoch 63/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1229 - val_loss: 0.4939
# Epoch 64/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1128 - val_loss: 0.4782
# Epoch 65/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1087 - val_loss: 0.5140
# Epoch 66/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1423 - val_loss: 0.4816
# Epoch 67/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1139 - val_loss: 0.5044
# Epoch 68/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1097 - val_loss: 0.5104
# Epoch 69/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1049 - val_loss: 0.5097
# Epoch 70/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1189 - val_loss: 0.5131
# Epoch 71/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1174 - val_loss: 0.4766
# Epoch 72/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1007 - val_loss: 0.4775
# Epoch 73/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1002 - val_loss: 0.4659
# Epoch 74/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1056 - val_loss: 0.4989
# Epoch 75/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1061 - val_loss: 0.4981
# Epoch 76/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1069 - val_loss: 0.5130
# Epoch 77/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1285 - val_loss: 0.4665
# Epoch 78/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1038 - val_loss: 0.5008
# Epoch 79/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1105 - val_loss: 0.5026
# Epoch 80/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0983 - val_loss: 0.5057
# Epoch 81/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0992 - val_loss: 0.4873
# Epoch 82/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1202 - val_loss: 0.5058
# Epoch 83/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0995 - val_loss: 0.5174
# Epoch 84/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1006 - val_loss: 0.4948
# Epoch 85/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0938 - val_loss: 0.5060
# Epoch 86/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1126 - val_loss: 0.5109
# Epoch 87/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1037 - val_loss: 0.5145
# Epoch 88/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0997 - val_loss: 0.5114
# Epoch 89/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1039 - val_loss: 0.5381
# Epoch 90/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0972 - val_loss: 0.5107
# Epoch 91/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1127 - val_loss: 0.5155
# Epoch 92/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0924 - val_loss: 0.4944
# Epoch 93/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0859 - val_loss: 0.5185
# Epoch 94/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0975 - val_loss: 0.4937
# Epoch 95/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1023 - val_loss: 0.4842
# Epoch 96/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0824 - val_loss: 0.5020
# Epoch 97/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1041 - val_loss: 0.4509
# Epoch 98/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1051 - val_loss: 0.5162
# Epoch 99/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0829 - val_loss: 0.4845
# Epoch 100/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0832 - val_loss: 0.5108
# Epoch 101/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0950 - val_loss: 0.4908
# Epoch 102/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0806 - val_loss: 0.4838
# Epoch 103/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0955 - val_loss: 0.4811
# Epoch 104/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0970 - val_loss: 0.4754
# Epoch 105/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0844 - val_loss: 0.4839
# Epoch 106/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0932 - val_loss: 0.4937
# Epoch 107/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0927 - val_loss: 0.4891
# Epoch 108/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0870 - val_loss: 0.4759
# Epoch 109/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0837 - val_loss: 0.4985
# Epoch 110/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0951 - val_loss: 0.5120
# Epoch 111/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0821 - val_loss: 0.4806
# Epoch 112/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1099 - val_loss: 0.4874
# Epoch 113/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1004 - val_loss: 0.4742
# Epoch 114/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0956 - val_loss: 0.4842
# Epoch 115/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0921 - val_loss: 0.4866
# Epoch 116/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0853 - val_loss: 0.4978
# Epoch 117/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0815 - val_loss: 0.4964
# Epoch 118/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0712 - val_loss: 0.4794
# Epoch 119/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0783 - val_loss: 0.4734
# Epoch 120/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0716 - val_loss: 0.5021
# Epoch 121/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0783 - val_loss: 0.4853
# Epoch 122/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0909 - val_loss: 0.4993
# Epoch 123/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0808 - val_loss: 0.5060
# Epoch 124/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0723 - val_loss: 0.5060
# Epoch 125/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0734 - val_loss: 0.4897
# Epoch 126/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0767 - val_loss: 0.5103
# Epoch 127/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0785 - val_loss: 0.5096
# Epoch 128/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0726 - val_loss: 0.5237
# Epoch 129/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0812 - val_loss: 0.5029
# Epoch 130/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0805 - val_loss: 0.5017
# Epoch 131/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0945 - val_loss: 0.5128
# Epoch 132/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0697 - val_loss: 0.5160
# Epoch 133/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0911 - val_loss: 0.5047
# Epoch 134/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0934 - val_loss: 0.4813
# Epoch 135/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0878 - val_loss: 0.4920
# Epoch 136/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0784 - val_loss: 0.5063
# Epoch 137/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0683 - val_loss: 0.5169
# Epoch 138/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0690 - val_loss: 0.5120
# Epoch 139/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0844 - val_loss: 0.4874
# Epoch 140/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0779 - val_loss: 0.4930
# Epoch 141/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0695 - val_loss: 0.5192
# Epoch 142/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0814 - val_loss: 0.5183
# Epoch 143/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0778 - val_loss: 0.4941
# Epoch 144/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0653 - val_loss: 0.4959
# Epoch 145/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0703 - val_loss: 0.5071
# Epoch 146/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0642 - val_loss: 0.5082
# Epoch 147/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0726 - val_loss: 0.5142
# Epoch 148/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0757 - val_loss: 0.5021
# Epoch 149/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0706 - val_loss: 0.5107
# Epoch 150/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0659 - val_loss: 0.4987
# Epoch 151/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0867 - val_loss: 0.5191
# Epoch 152/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0821 - val_loss: 0.5054
# Epoch 153/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0720 - val_loss: 0.5059
# Epoch 154/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0745 - val_loss: 0.5110
# Epoch 155/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0561 - val_loss: 0.4964
# Epoch 156/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0714 - val_loss: 0.5053
# Epoch 157/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0756 - val_loss: 0.4841
# Epoch 158/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0750 - val_loss: 0.5260
# Epoch 159/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0596 - val_loss: 0.4993
# Epoch 160/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0674 - val_loss: 0.4879
# Epoch 161/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0721 - val_loss: 0.4937
# Epoch 162/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0708 - val_loss: 0.5002
# Epoch 163/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0688 - val_loss: 0.5036
# Epoch 164/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0822 - val_loss: 0.4899
# Epoch 165/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0620 - val_loss: 0.4938
# Epoch 166/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0612 - val_loss: 0.4985
# Epoch 167/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0495 - val_loss: 0.4967
# Epoch 168/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0738 - val_loss: 0.4827
# Epoch 169/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0801 - val_loss: 0.4921
# Epoch 170/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0795 - val_loss: 0.4818
# Epoch 171/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0635 - val_loss: 0.4918
# Epoch 172/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0718 - val_loss: 0.4951
# Epoch 173/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0710 - val_loss: 0.4853
# Epoch 174/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520 - val_loss: 0.5040
# Epoch 175/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0629 - val_loss: 0.5065
# Epoch 176/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0757 - val_loss: 0.5139
# Epoch 177/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0618 - val_loss: 0.5168
# Epoch 178/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0652 - val_loss: 0.5011
# Epoch 179/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0672 - val_loss: 0.5126
# Epoch 180/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0689 - val_loss: 0.5099
# Epoch 181/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0468 - val_loss: 0.5177
# Epoch 182/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0736 - val_loss: 0.5286
# Epoch 183/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0788 - val_loss: 0.5074
# Epoch 184/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0690 - val_loss: 0.4972
# Epoch 185/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0591 - val_loss: 0.5008
# Epoch 186/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0606 - val_loss: 0.4697
# Epoch 187/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0517 - val_loss: 0.4783
# Epoch 188/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0572 - val_loss: 0.4787
# Epoch 189/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0540 - val_loss: 0.4897
# Epoch 190/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0572 - val_loss: 0.5100
# Epoch 191/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0791 - val_loss: 0.5007
# Epoch 192/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0603 - val_loss: 0.5066
# Epoch 193/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0541 - val_loss: 0.5049
# Epoch 194/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0537 - val_loss: 0.4828
# Epoch 195/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0636 - val_loss: 0.5266
# Epoch 196/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0794 - val_loss: 0.4895
# Epoch 197/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0582 - val_loss: 0.4834
# Epoch 198/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0810 - val_loss: 0.4823
# Epoch 199/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0601 - val_loss: 0.4754
# Epoch 200/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0704 - val_loss: 0.4769
# Epoch 201/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0469 - val_loss: 0.4881
# Epoch 202/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0575 - val_loss: 0.4841
# Epoch 203/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0724 - val_loss: 0.4913
# Epoch 204/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0672 - val_loss: 0.4769
# Epoch 205/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0622 - val_loss: 0.4868
# Epoch 206/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0491 - val_loss: 0.4908
# Epoch 207/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0455 - val_loss: 0.5216
# Epoch 208/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0499 - val_loss: 0.5068
# Epoch 209/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0743 - val_loss: 0.5193
# Epoch 210/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0769 - val_loss: 0.5033
# Epoch 211/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0621 - val_loss: 0.4980
# Epoch 212/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0648 - val_loss: 0.5061
# Epoch 213/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0520 - val_loss: 0.5055
# Epoch 214/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0596 - val_loss: 0.5183
# Epoch 215/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0648 - val_loss: 0.4902
# Epoch 216/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0613 - val_loss: 0.5115
# Epoch 217/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0585 - val_loss: 0.5309
# Epoch 218/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0734 - val_loss: 0.5029
# Epoch 219/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0623 - val_loss: 0.4850
# Epoch 220/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0489 - val_loss: 0.4965
# Epoch 221/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0526 - val_loss: 0.4998
# Epoch 222/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0655 - val_loss: 0.4855
# Epoch 223/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0769 - val_loss: 0.4944
# Epoch 224/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400 - val_loss: 0.5056
# Epoch 225/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - val_loss: 0.5211
# Epoch 226/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0431 - val_loss: 0.4950
# Epoch 227/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0403 - val_loss: 0.5196
# Epoch 228/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0408 - val_loss: 0.5127
# Epoch 229/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0673 - val_loss: 0.5041
# Epoch 230/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0619 - val_loss: 0.5171
# Epoch 231/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0676 - val_loss: 0.4853
# Epoch 232/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0735 - val_loss: 0.4991
# Epoch 233/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0564 - val_loss: 0.5156
# Epoch 234/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0385 - val_loss: 0.5172
# Epoch 235/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0408 - val_loss: 0.5148
# Epoch 236/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0417 - val_loss: 0.5026
# Epoch 237/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0516 - val_loss: 0.5202
# Epoch 238/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0658 - val_loss: 0.5020
# Epoch 239/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0578 - val_loss: 0.5196
# Epoch 240/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0437 - val_loss: 0.5105
# Epoch 241/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0742 - val_loss: 0.4871
# Epoch 242/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - val_loss: 0.4932
# Epoch 243/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0506 - val_loss: 0.5091
# Epoch 244/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0564 - val_loss: 0.4733
# Epoch 245/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0643 - val_loss: 0.4940
# Epoch 246/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0534 - val_loss: 0.5132
# Epoch 247/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0525 - val_loss: 0.5173
# Epoch 248/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0741 - val_loss: 0.5028
# Epoch 249/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0573 - val_loss: 0.5022
# Epoch 250/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0487 - val_loss: 0.5102
# Epoch 251/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0453 - val_loss: 0.4973
# Epoch 252/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0638 - val_loss: 0.5045
# Epoch 253/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - val_loss: 0.4926
# Epoch 254/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0473 - val_loss: 0.5138
# Epoch 255/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580 - val_loss: 0.4955
# Epoch 256/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0501 - val_loss: 0.5018
# Epoch 257/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0410 - val_loss: 0.5010
# Epoch 258/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0710 - val_loss: 0.4836
# Epoch 259/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0695 - val_loss: 0.5330
# Epoch 260/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - val_loss: 0.5057
# Epoch 261/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - val_loss: 0.5201
# Epoch 262/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0438 - val_loss: 0.5137
# Epoch 263/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0419 - val_loss: 0.4997
# Epoch 264/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0682 - val_loss: 0.4772
# Epoch 265/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0696 - val_loss: 0.5014
# Epoch 266/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0469 - val_loss: 0.4992
# Epoch 267/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0437 - val_loss: 0.5075
# Epoch 268/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0437 - val_loss: 0.4994
# Epoch 269/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0466 - val_loss: 0.4836
# Epoch 270/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0434 - val_loss: 0.5212
# Epoch 271/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0624 - val_loss: 0.5289
# Epoch 272/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0674 - val_loss: 0.5200
# Epoch 273/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0707 - val_loss: 0.5055
# Epoch 274/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0444 - val_loss: 0.5176
# Epoch 275/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0457 - val_loss: 0.5137
# Epoch 276/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - val_loss: 0.4902
# Epoch 277/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0381 - val_loss: 0.5075
# Epoch 278/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - val_loss: 0.5182
# Epoch 279/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - val_loss: 0.4985
# Epoch 280/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0425 - val_loss: 0.4972
# Epoch 281/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0493 - val_loss: 0.5110
# Epoch 282/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443 - val_loss: 0.5142
# Epoch 283/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0396 - val_loss: 0.5340
# Epoch 284/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0677 - val_loss: 0.4934
# Epoch 285/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0632 - val_loss: 0.5250
# Epoch 286/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0425 - val_loss: 0.5124
# Epoch 287/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0396 - val_loss: 0.5186
# Epoch 288/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - val_loss: 0.4974
# Epoch 289/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0374 - val_loss: 0.4945
# Epoch 290/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0437 - val_loss: 0.5175
# Epoch 291/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0463 - val_loss: 0.4814
# Epoch 292/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0557 - val_loss: 0.5129
# Epoch 293/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0558 - val_loss: 0.4977
# Epoch 294/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0562 - val_loss: 0.5217
# Epoch 295/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0375 - val_loss: 0.5217
# Epoch 296/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0337 - val_loss: 0.5101
# Epoch 297/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0399 - val_loss: 0.5284
# Epoch 298/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0497 - val_loss: 0.5091
# Epoch 299/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0725 - val_loss: 0.4950
# Epoch 300/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0415 - val_loss: 0.5047
# Epoch 301/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0349 - val_loss: 0.5365
# Epoch 302/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0423 - val_loss: 0.5076
# Epoch 303/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0461 - val_loss: 0.4996
# Epoch 304/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0381 - val_loss: 0.5263
# Epoch 305/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400 - val_loss: 0.5229
# Epoch 306/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0446 - val_loss: 0.4938
# Epoch 307/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0438 - val_loss: 0.5142
# Epoch 308/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0423 - val_loss: 0.5109
# Epoch 309/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0351 - val_loss: 0.5286
# Epoch 310/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0571 - val_loss: 0.4767
# Epoch 311/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0615 - val_loss: 0.4892
# Epoch 312/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0355 - val_loss: 0.5242
# Epoch 313/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0371 - val_loss: 0.4967
# Epoch 314/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0487 - val_loss: 0.5167
# Epoch 315/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459 - val_loss: 0.5341
# Epoch 316/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0571 - val_loss: 0.5024
# Epoch 317/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0334 - val_loss: 0.5217
# Epoch 318/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0354 - val_loss: 0.5225
# Epoch 319/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0405 - val_loss: 0.5014
# Epoch 320/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0504 - val_loss: 0.5229
# Epoch 321/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0633 - val_loss: 0.4916
# Epoch 322/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451 - val_loss: 0.5059
# Epoch 323/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0394 - val_loss: 0.5215
# Epoch 324/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0422 - val_loss: 0.5153
# Epoch 325/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0338 - val_loss: 0.4927
# Epoch 326/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - val_loss: 0.5025
# Epoch 327/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0423 - val_loss: 0.5085
# Epoch 328/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0422 - val_loss: 0.5024
# Epoch 329/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0490 - val_loss: 0.5088
# Epoch 330/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0379 - val_loss: 0.5111
# Epoch 331/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0547 - val_loss: 0.4926
# Epoch 332/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0504 - val_loss: 0.5095
# Epoch 333/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0778 - val_loss: 0.5116
# Epoch 334/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0542 - val_loss: 0.4974
# Epoch 335/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0401 - val_loss: 0.5023
# Epoch 336/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0390 - val_loss: 0.5204
# Epoch 337/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0304 - val_loss: 0.5227
# Epoch 338/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0406 - val_loss: 0.5287
# Epoch 339/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0547 - val_loss: 0.5017
# Epoch 340/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0472 - val_loss: 0.4978
# Epoch 341/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0479 - val_loss: 0.5055
# Epoch 342/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0308 - val_loss: 0.5229
# Epoch 343/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - val_loss: 0.5194
# Epoch 344/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0389 - val_loss: 0.5094
# Epoch 345/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0394 - val_loss: 0.5206
# Epoch 346/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0394 - val_loss: 0.5227
# Epoch 347/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0351 - val_loss: 0.5206
# Epoch 348/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400 - val_loss: 0.5191
# Epoch 349/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0257 - val_loss: 0.5164
# Epoch 350/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0518 - val_loss: 0.5242
# Epoch 351/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0399 - val_loss: 0.5336
# Epoch 352/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - val_loss: 0.5172
# Epoch 353/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - val_loss: 0.5240
# Epoch 354/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0379 - val_loss: 0.5180
# Epoch 355/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0330 - val_loss: 0.5294
# Epoch 356/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0235 - val_loss: 0.5275
# Epoch 357/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0424 - val_loss: 0.5274
# Epoch 358/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0631 - val_loss: 0.5065
# Epoch 359/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0447 - val_loss: 0.5041
# Epoch 360/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0366 - val_loss: 0.5117
# Epoch 361/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.5225
# Epoch 362/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.5342
# Epoch 363/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0302 - val_loss: 0.5334
# Epoch 364/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0682 - val_loss: 0.5329
# Epoch 365/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0748 - val_loss: 0.5140
# Epoch 366/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0364 - val_loss: 0.5349
# Epoch 367/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0237 - val_loss: 0.5295
# Epoch 368/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0394 - val_loss: 0.5194
# Epoch 369/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - val_loss: 0.5204
# Epoch 370/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0296 - val_loss: 0.5270
# Epoch 371/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0388 - val_loss: 0.5234
# Epoch 372/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0388 - val_loss: 0.5146
# Epoch 373/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0453 - val_loss: 0.5270
# Epoch 374/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0368 - val_loss: 0.5310
# Epoch 375/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - val_loss: 0.5429
# Epoch 376/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0290 - val_loss: 0.5360
# Epoch 377/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0233 - val_loss: 0.5226
# Epoch 378/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0211 - val_loss: 0.5402
# Epoch 379/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0505 - val_loss: 0.5175
# Epoch 380/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0408 - val_loss: 0.5339
# Epoch 381/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0588 - val_loss: 0.5195
# Epoch 382/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0448 - val_loss: 0.5175
# Epoch 383/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0288 - val_loss: 0.5256
# Epoch 384/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0303 - val_loss: 0.5346
# Epoch 385/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0308 - val_loss: 0.5347
# Epoch 386/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0539 - val_loss: 0.5178
# Epoch 387/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0331 - val_loss: 0.5249
# Epoch 388/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333 - val_loss: 0.5213
# Epoch 389/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0573 - val_loss: 0.5173
# Epoch 390/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0427 - val_loss: 0.5374
# Epoch 391/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0341 - val_loss: 0.5248
# Epoch 392/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0277 - val_loss: 0.5350
# Epoch 393/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0322 - val_loss: 0.5341
# Epoch 394/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0489 - val_loss: 0.5491
# Epoch 395/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0547 - val_loss: 0.5305
# Epoch 396/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - val_loss: 0.5197
# Epoch 397/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0355 - val_loss: 0.5106
# Epoch 398/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0198 - val_loss: 0.5333
# Epoch 399/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0495 - val_loss: 0.5320
# Epoch 400/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0259 - val_loss: 0.5454
# Epoch 401/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0391 - val_loss: 0.5408
# Epoch 402/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0396 - val_loss: 0.5191
# Epoch 403/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - val_loss: 0.5348
# Epoch 404/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - val_loss: 0.5136
# Epoch 405/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0377 - val_loss: 0.5230
# Epoch 406/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0357 - val_loss: 0.5326
# Epoch 407/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - val_loss: 0.5257
# Epoch 408/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0293 - val_loss: 0.5256
# Epoch 409/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0328 - val_loss: 0.5266
# Epoch 410/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0307 - val_loss: 0.5386
# Epoch 411/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0324 - val_loss: 0.5165
# Epoch 412/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262 - val_loss: 0.5254
# Epoch 413/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0242 - val_loss: 0.5405
# Epoch 414/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451 - val_loss: 0.5285
# Epoch 415/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - val_loss: 0.5301
# Epoch 416/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0337 - val_loss: 0.5168
# Epoch 417/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0308 - val_loss: 0.5037
# Epoch 418/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0357 - val_loss: 0.5292
# Epoch 419/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - val_loss: 0.5311
# Epoch 420/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - val_loss: 0.5148
# Epoch 421/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0401 - val_loss: 0.5107
# Epoch 422/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0292 - val_loss: 0.5245
# Epoch 423/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0699 - val_loss: 0.5456
# Epoch 424/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0535 - val_loss: 0.5172
# Epoch 425/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0777 - val_loss: 0.4876
# Epoch 426/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0428 - val_loss: 0.4953
# Epoch 427/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0250 - val_loss: 0.5140
# Epoch 428/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0230 - val_loss: 0.5209
# Epoch 429/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0329 - val_loss: 0.5231
# Epoch 430/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0412 - val_loss: 0.5306
# Epoch 431/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0254 - val_loss: 0.5219
# Epoch 432/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0287 - val_loss: 0.5208
# Epoch 433/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0353 - val_loss: 0.5204
# Epoch 434/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0250 - val_loss: 0.5173
# Epoch 435/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.5123
# Epoch 436/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0538 - val_loss: 0.5010
# Epoch 437/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0473 - val_loss: 0.5153
# Epoch 438/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0365 - val_loss: 0.5203
# Epoch 439/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.4956
# Epoch 440/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0261 - val_loss: 0.5182
# Epoch 441/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0346 - val_loss: 0.5196
# Epoch 442/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0451 - val_loss: 0.5136
# Epoch 443/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0339 - val_loss: 0.5029
# Epoch 444/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0310 - val_loss: 0.5145
# Epoch 445/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0263 - val_loss: 0.5200
# Epoch 446/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0401 - val_loss: 0.5334
# Epoch 447/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0265 - val_loss: 0.5021
# Epoch 448/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0299 - val_loss: 0.5140
# Epoch 449/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0410 - val_loss: 0.5365
# Epoch 450/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0244 - val_loss: 0.5317
# Epoch 451/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0183 - val_loss: 0.5457
# Epoch 452/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0278 - val_loss: 0.5032
# Epoch 453/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - val_loss: 0.5083
# Epoch 454/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0379 - val_loss: 0.5236
# Epoch 455/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0255 - val_loss: 0.5077
# Epoch 456/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0308 - val_loss: 0.5184
# Epoch 457/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0401 - val_loss: 0.5241
# Epoch 458/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0305 - val_loss: 0.5246
# Epoch 459/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0411 - val_loss: 0.5356
# Epoch 460/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0433 - val_loss: 0.5236
# Epoch 461/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0366 - val_loss: 0.5443
# Epoch 462/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0320 - val_loss: 0.5368
# Epoch 463/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0297 - val_loss: 0.5411
# Epoch 464/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0638 - val_loss: 0.4996
# Epoch 465/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0286 - val_loss: 0.5265
# Epoch 466/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0256 - val_loss: 0.5204
# Epoch 467/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0150 - val_loss: 0.5343
# Epoch 468/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0246 - val_loss: 0.5196
# Epoch 469/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0396 - val_loss: 0.5089
# Epoch 470/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333 - val_loss: 0.5422
# Epoch 471/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0357 - val_loss: 0.5326
# Epoch 472/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0406 - val_loss: 0.5320
# Epoch 473/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0353 - val_loss: 0.5072
# Epoch 474/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0530 - val_loss: 0.5251
# Epoch 475/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0454 - val_loss: 0.5040
# Epoch 476/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0414 - val_loss: 0.5290
# Epoch 477/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0441 - val_loss: 0.5212
# Epoch 478/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0539 - val_loss: 0.5050
# Epoch 479/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0265 - val_loss: 0.4985
# Epoch 480/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0349 - val_loss: 0.5169
# Epoch 481/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0187 - val_loss: 0.5201
# Epoch 482/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0285 - val_loss: 0.5210
# Epoch 483/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0253 - val_loss: 0.5087
# Epoch 484/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0275 - val_loss: 0.5580
# Epoch 485/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.5386
# Epoch 486/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0283 - val_loss: 0.5352
# Epoch 487/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0381 - val_loss: 0.4806
# Epoch 488/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0378 - val_loss: 0.5250
# Epoch 489/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0262 - val_loss: 0.5367
# Epoch 490/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0541 - val_loss: 0.5275
# Epoch 491/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0298 - val_loss: 0.5406
# Epoch 492/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0351 - val_loss: 0.4932
# Epoch 493/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0313 - val_loss: 0.5186
# Epoch 494/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0190 - val_loss: 0.5332
# Epoch 495/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0208 - val_loss: 0.5445
# Epoch 496/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0281 - val_loss: 0.5391
# Epoch 497/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0369 - val_loss: 0.5209
# Epoch 498/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0358 - val_loss: 0.5315
# Epoch 499/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0299 - val_loss: 0.5152
# Epoch 500/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0586 - val_loss: 0.4729
# Epoch 501/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - val_loss: 0.5255
# Epoch 502/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0480 - val_loss: 0.5363
# Epoch 503/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0329 - val_loss: 0.5301
# Epoch 504/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0220 - val_loss: 0.5108
# Epoch 505/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0330 - val_loss: 0.5168
# Epoch 506/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - val_loss: 0.5190
# Epoch 507/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0432 - val_loss: 0.5237
# Epoch 508/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0383 - val_loss: 0.5249
# Epoch 509/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0367 - val_loss: 0.5100
# Epoch 510/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0211 - val_loss: 0.5158
# Epoch 511/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0217 - val_loss: 0.5126
# Epoch 512/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0385 - val_loss: 0.5063
# Epoch 513/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0289 - val_loss: 0.5306
# Epoch 514/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0351 - val_loss: 0.5349
# Epoch 515/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0234 - val_loss: 0.5160
# Epoch 516/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - val_loss: 0.5407
# Epoch 517/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0320 - val_loss: 0.5364
# Epoch 518/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0483 - val_loss: 0.5334
# Epoch 519/1000
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0279 - val_loss: 0.5355

# %% [markdown]
# We can view the training losses to determine whether the model is performing as expected.

# %%
# Plot the relevant losses
plt.semilogy(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.xlabel('Epochs')
plt.show()

# %% [markdown]
# We can view the accuracy of the model by rounding the predictions to effectively threshold a binary outcome around 0.5. To see the actual distribution of the the outputs plot a distribution of the outputs for both the training and validation predictions.

# %%
def get_accuracy(y_true, y_pred):
    # round up/down to get a binary prediction. This could be modified with different thresholds
    rounded_y_pred = np.round(y_pred)

    # find the accuracy py finding when the difference is 0
    diff = y_true - rounded_y_pred
    return np.array(diff == 0, dtype=int).sum() / len(diff)

# %%
# get the training predictions
preds = quant_mod.predict(train_X)
y_train_acc = get_accuracy(train_y, preds) * 100

# get the validation predictions
preds_val = quant_mod.predict(val_X)
y_val_acc = get_accuracy(val_y, preds_val) * 100

print(
    '-' * 10
    + ' Model Accuracy '
    + '-' * 10
    + '\nTrain: \t %.2f %%' % y_train_acc
    + '\nVal: \t %.2f %%\n' % y_val_acc
    + '-' * 36
)
# Out:
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ---------- Model Accuracy ----------
# Train: 	 99.78 %
# Val: 	 95.71 %
# ------------------------------------

# %%
# plot a histogram of all the predictions
plt.hist(preds, bins=np.linspace(0, 1, 101), label='prediction on training dataset')
plt.hist(preds_val, bins=np.linspace(0, 1, 101), label='prediction on validation dataset')
plt.ylabel('Counts')
plt.xlabel('Output value')
plt.legend()
plt.show()

# %% [markdown]
# Test the model on unseen data (data not used in training).
#
# As the training and validation sets were created using half of the datapoints generated at the beginning of the script, we'll use the second half to test the model on unseen dat.

# %%
# construct the arrays, we will use the second half of the original signals
X_test = np.concatenate([sigs_non[len(sigs_non) // 2 :], sigs_dfct[len(sigs_non) // 2 :]], axis=0)
y_test = np.concatenate([np.zeros(len(sigs_non) // 2), np.ones(len(sigs_non) // 2)], axis=0)

# shuffle the arrays to avoid training bias
random_idx_test = [i for i in range(len(y_test))]
np.random.shuffle(random_idx_test)
X_test = X_test[random_idx_test]
y_test = y_test[random_idx_test].reshape(-1, 1)

# %%
# get the training predictions
preds_test = quant_mod.predict(X_test)
y_test_acc = get_accuracy(y_test, preds_test) * 100

print('-' * 10 + ' Model Accuracy ' + '-' * 10 + '\nTrain: \t %.2f %%' % y_test_acc)

# plot a histogram of all the predictions
plt.hist(preds_test, bins=np.linspace(0, 1, 101))
plt.ylabel('Counts')
plt.xlabel('Output value')
plt.show()
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step
# ---------- Model Accuracy ----------
# Train: 	 95.00 %

# %%
save_linn(quant_mod, input_channels=1, output_channels=1, file_name='classifier.linn')
# Out:
# Skipping layer 0 with type <class 'keras.src.layers.core.input_layer.InputLayer'>
# Skipping layer 2 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 4 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 6 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 8 with type <class 'moku.nn._linn.OutputClipLayer'>
# Skipping layer 10 with type <class 'moku.nn._linn.OutputClipLayer'>
# Network latency approx. 355 cycles
