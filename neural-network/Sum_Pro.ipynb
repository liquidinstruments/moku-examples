# %% [markdown]
# # Outputting a weighted sum of inputs
#
# In this tutorial, you will learn the fundamentals of using the provided neural network library for training a Moku Neural Network to deploy on Moku:Pro. This library uses the [Tensorflow](https://www.tensorflow.org/) implementation of [Keras](https://www.tensorflow.org/guide/keras) to instill best practices for deploying an FPGA-based neural network. In this example, we will train a basic model to output a weighted sum of the input chnnels with an optional bias/offset term using a single layer with a single neuron.

# %%
import matplotlib.pyplot as plt
import numpy as np

from moku.nn import LinnModel, save_linn
# Out:
# 2025-11-17 10:49:19.372943: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-17 10:49:19.713194: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-17 10:49:21.364942: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# # Step 1: Generate input (3 channels) and output (one channel) data for training
#
# Generate training data and plot the simulated signals to verify them. You can also choose to use Moku to produce training data.

# %%
nPts = 1024
nCycles = 5
x = np.linspace(0, nCycles * 2 * np.pi, nPts)

in1 = np.sin(x)

in2 = np.sign(in1)

in3 = 1 / np.pi * ((x % (2 * np.pi)) - np.pi)

offset = 0.1
amp1 = 0.1
amp2 = 0.2
amp3 = 0.3

out = amp1 * in1 + amp2 * in2 + amp3 * in3 + offset

plt.figure()
plt.plot(in1)
plt.plot(in2)
plt.plot(in3)
plt.title('Inputs')

plt.figure()
plt.plot(out)
plt.title('Desired output')
# Out:
# Text(0.5, 1.0, 'Desired output')

# %% [markdown]
# # Step 2: Defining the model and train the neural network
#
# Now that we have defined the training data we need to define a model which we will then subsequently train. A neural network is made of succesive layers of connected neurons that implement a generally non-linear mapping of a linear transform: $A(Wx + b)$, where $W$ is the weight matrix, $x$ is an input vector, $b$ is a bias vector and $A$ is the activation function. By successively stacking and connecting arbitrarily large numbers of artificial neurons, a neural network becomes a unviersal approximator. While there are many different types of neural networks, the Moku FPGA currently only supports densely connected feedforward networks. More information on these type of networks, otherwise known as multilayer perceptrons, can be found here: [Goodfellow-Ch6](https://www.deeplearningbook.org/contents/mlp.html).
#
# We also reshape the data to reflect that we have N number of training examples of size 1. In general, training data should allow for the mapping $(N, M)\mapsto(N, K)$ where N is the number of training examples, M is the input feature dimension and K is the output feature dimension. In this case we are looking to map $X \mapsto Y$ where both X and Y have shape (N, 1).

# %%
# Reshape the inputs, ready for training. Each `data point' is three inputs and one output
inputs = np.vstack((in1, in2, in3)).transpose()  # Shape is now nPts x 3
out.shape = [nPts, 1]  # Shape is now nPts x 1

# %% [markdown]
# We need to define the model structure that we will use to represent the functional mapping. To do this, we will define a simple model with only one dense layer of a single neuron and a linear activation function. We provide a model definition as a list of tuples, where each tuple can take the form: `(layer_size, activation)`.
#
# Build the neural network model. Skip the I/O scaling as the data is sufficient for training,
# Note that if you add scaling here, you'll need to apply the same scaling in the Moku Neural Network instrument at
# runtime.

# %%
linn_model = LinnModel()
linn_model.set_training_data(inputs, out, scale=False)

model_definition = [
    (1, 'linear')
]  # A linear model should give a perfect prediction in this contrived case
# Try some of the others below

# model_definition = [ (4, 'relu'), (4, 'relu')] # ReLU activation not great on signal reconstruction
# model_definition = [ (4, 'tanh'), (4, 'tanh')] # tanh has a range of +-1 which is more "voltage-like"
# model_definition = [ (16, 'tanh'), (16, 'tanh')] # A few more degrees of freedom to play around with
# model_definition = [ (100, 'tanh'), (100, 'tanh'), (100, 'tanh'), (100, 'tanh'), (100, 'tanh')] # Biggest Moku can fit, can overfit!

linn_model.construct_model(model_definition)
# Out:
# 2025-11-17 10:49:21.937315: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# Here we can see our dense layers that match the size that we defined. There are a number of intermediate layers listed as `output_clip_layer` which can be ignored. These layers are a byproduct of the quantisation for the Moku implmentation and are automatically added by the quantised model.
#
# Now that we have defined our model, we need to train it so that it will represent our desired mapping. This is as simple as calling the `fit_model()` function with a few simple arguments. We will allow our model to train for 500 epochs (training steps) and will pass our validation data that we used earlier.
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> For those familiar with Keras, keyword arguments can be passed to the Keras 'fit' function via the 'fit_model' function.
# </div>

# %%
# %%
# Train the model. This simple model converges quickly, so an early stopping config terminates training much more quickly.
history = linn_model.fit_model(epochs=500, validation_split=0.1, es_config={'patience': 10})
# Out:
# Value for monitor missing. Using default:val_loss.
# Value for restore missing. Using default:False.
# Epoch 1/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0406 - val_loss: 0.8079
# Epoch 2/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9201 - val_loss: 0.7448
# Epoch 3/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8035 - val_loss: 0.6792
# Epoch 4/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6995 - val_loss: 0.6182
# Epoch 5/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6074 - val_loss: 0.5555
# Epoch 6/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5275 - val_loss: 0.5018
# Epoch 7/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4575 - val_loss: 0.4517
# Epoch 8/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3967 - val_loss: 0.4055
# Epoch 9/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3440 - val_loss: 0.3641
# Epoch 10/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2987 - val_loss: 0.3271
# Epoch 11/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2596 - val_loss: 0.2938
# Epoch 12/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2261 - val_loss: 0.2624
# Epoch 13/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1977 - val_loss: 0.2344
# Epoch 14/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1736 - val_loss: 0.2113
# Epoch 15/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1534 - val_loss: 0.1904
# Epoch 16/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1364 - val_loss: 0.1721
# Epoch 17/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1222 - val_loss: 0.1562
# Epoch 18/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1105 - val_loss: 0.1431
# Epoch 19/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1008 - val_loss: 0.1318
# Epoch 20/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0929 - val_loss: 0.1221
# Epoch 21/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0864 - val_loss: 0.1146
# Epoch 22/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0812 - val_loss: 0.1076
# Epoch 23/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0768 - val_loss: 0.1015
# Epoch 24/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0734 - val_loss: 0.0970
# Epoch 25/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0704 - val_loss: 0.0928
# Epoch 26/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0681 - val_loss: 0.0899
# Epoch 27/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0662 - val_loss: 0.0864
# Epoch 28/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0645 - val_loss: 0.0845
# Epoch 29/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0632 - val_loss: 0.0824
# Epoch 30/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0619 - val_loss: 0.0808
# Epoch 31/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0609 - val_loss: 0.0791
# Epoch 32/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0599 - val_loss: 0.0778
# Epoch 33/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0591 - val_loss: 0.0764
# Epoch 34/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0583 - val_loss: 0.0751
# Epoch 35/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0575 - val_loss: 0.0741
# Epoch 36/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0567 - val_loss: 0.0731
# Epoch 37/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0560 - val_loss: 0.0719
# Epoch 38/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0553 - val_loss: 0.0710
# Epoch 39/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0545 - val_loss: 0.0699
# Epoch 40/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0538 - val_loss: 0.0689
# Epoch 41/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - val_loss: 0.0679
# Epoch 42/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - val_loss: 0.0670
# Epoch 43/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - val_loss: 0.0659
# Epoch 44/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0510 - val_loss: 0.0648
# Epoch 45/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0502 - val_loss: 0.0641
# Epoch 46/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0495 - val_loss: 0.0630
# Epoch 47/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0488 - val_loss: 0.0621
# Epoch 48/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0481 - val_loss: 0.0611
# Epoch 49/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - val_loss: 0.0600
# Epoch 50/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0466 - val_loss: 0.0592
# Epoch 51/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0459 - val_loss: 0.0584
# Epoch 52/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0452 - val_loss: 0.0573
# Epoch 53/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0444 - val_loss: 0.0564
# Epoch 54/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0437 - val_loss: 0.0553
# Epoch 55/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - val_loss: 0.0545
# Epoch 56/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0422 - val_loss: 0.0535
# Epoch 57/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0415 - val_loss: 0.0526
# Epoch 58/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0408 - val_loss: 0.0516
# Epoch 59/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0400 - val_loss: 0.0507
# Epoch 60/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0393 - val_loss: 0.0497
# Epoch 61/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0386 - val_loss: 0.0486
# Epoch 62/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0379 - val_loss: 0.0479
# Epoch 63/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0371 - val_loss: 0.0469
# Epoch 64/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0364 - val_loss: 0.0460
# Epoch 65/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - val_loss: 0.0451
# Epoch 66/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0350 - val_loss: 0.0441
# Epoch 67/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0343 - val_loss: 0.0431
# Epoch 68/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0336 - val_loss: 0.0423
# Epoch 69/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0329 - val_loss: 0.0414
# Epoch 70/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0322 - val_loss: 0.0406
# Epoch 71/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0315 - val_loss: 0.0396
# Epoch 72/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0308 - val_loss: 0.0387
# Epoch 73/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0301 - val_loss: 0.0378
# Epoch 74/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.0368
# Epoch 75/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0288 - val_loss: 0.0361
# Epoch 76/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0281 - val_loss: 0.0350
# Epoch 77/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0274 - val_loss: 0.0345
# Epoch 78/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0268 - val_loss: 0.0335
# Epoch 79/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0261 - val_loss: 0.0327
# Epoch 80/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255 - val_loss: 0.0319
# Epoch 81/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0248 - val_loss: 0.0311
# Epoch 82/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0242 - val_loss: 0.0303
# Epoch 83/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0236 - val_loss: 0.0294
# Epoch 84/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.0287
# Epoch 85/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0224 - val_loss: 0.0279
# Epoch 86/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218 - val_loss: 0.0271
# Epoch 87/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0212 - val_loss: 0.0264
# Epoch 88/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0206 - val_loss: 0.0256
# Epoch 89/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200 - val_loss: 0.0250
# Epoch 90/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0194 - val_loss: 0.0241
# Epoch 91/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - val_loss: 0.0234
# Epoch 92/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183 - val_loss: 0.0228
# Epoch 93/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0220
# Epoch 94/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172 - val_loss: 0.0214
# Epoch 95/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0208
# Epoch 96/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - val_loss: 0.0201
# Epoch 97/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0157 - val_loss: 0.0194
# Epoch 98/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0152 - val_loss: 0.0188
# Epoch 99/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0147 - val_loss: 0.0182
# Epoch 100/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0142 - val_loss: 0.0175
# Epoch 101/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0137 - val_loss: 0.0170
# Epoch 102/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - val_loss: 0.0164
# Epoch 103/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - val_loss: 0.0159
# Epoch 104/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - val_loss: 0.0153
# Epoch 105/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0119 - val_loss: 0.0147
# Epoch 106/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - val_loss: 0.0142
# Epoch 107/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - val_loss: 0.0137
# Epoch 108/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - val_loss: 0.0131
# Epoch 109/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - val_loss: 0.0127
# Epoch 110/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - val_loss: 0.0122
# Epoch 111/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - val_loss: 0.0117
# Epoch 112/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - val_loss: 0.0112
# Epoch 113/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - val_loss: 0.0108
# Epoch 114/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0084 - val_loss: 0.0104
# Epoch 115/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - val_loss: 0.0100
# Epoch 116/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - val_loss: 0.0095
# Epoch 117/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - val_loss: 0.0091
# Epoch 118/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 119/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - val_loss: 0.0083
# Epoch 120/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - val_loss: 0.0080
# Epoch 121/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 122/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 123/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 124/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - val_loss: 0.0066
# Epoch 125/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0063
# Epoch 126/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 127/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 128/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 129/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - val_loss: 0.0051
# Epoch 130/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - val_loss: 0.0049
# Epoch 131/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - val_loss: 0.0047
# Epoch 132/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 133/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 134/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 135/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 136/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 137/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 138/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 139/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 140/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 141/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 142/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 143/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 144/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 145/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 146/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 147/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 148/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 149/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 150/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 151/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 152/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 153/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8734e-04 - val_loss: 0.0012
# Epoch 154/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1896e-04 - val_loss: 0.0011
# Epoch 155/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5337e-04 - val_loss: 0.0010
# Epoch 156/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9310e-04 - val_loss: 9.6002e-04
# Epoch 157/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3735e-04 - val_loss: 8.6742e-04
# Epoch 158/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8102e-04 - val_loss: 8.1583e-04
# Epoch 159/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2939e-04 - val_loss: 7.4669e-04
# Epoch 160/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8101e-04 - val_loss: 6.9230e-04
# Epoch 161/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3639e-04 - val_loss: 6.3827e-04
# Epoch 162/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9441e-04 - val_loss: 5.8740e-04
# Epoch 163/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5638e-04 - val_loss: 5.3845e-04
# Epoch 164/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1842e-04 - val_loss: 4.9898e-04
# Epoch 165/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8430e-04 - val_loss: 4.5656e-04
# Epoch 166/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5235e-04 - val_loss: 4.1843e-04
# Epoch 167/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2239e-04 - val_loss: 3.8351e-04
# Epoch 168/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9562e-04 - val_loss: 3.4794e-04
# Epoch 169/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7012e-04 - val_loss: 3.1894e-04
# Epoch 170/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4608e-04 - val_loss: 2.9343e-04
# Epoch 171/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2429e-04 - val_loss: 2.6328e-04
# Epoch 172/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0395e-04 - val_loss: 2.4035e-04
# Epoch 173/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8552e-04 - val_loss: 2.1866e-04
# Epoch 174/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6809e-04 - val_loss: 1.9738e-04
# Epoch 175/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5249e-04 - val_loss: 1.8076e-04
# Epoch 176/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3781e-04 - val_loss: 1.6202e-04
# Epoch 177/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2474e-04 - val_loss: 1.4628e-04
# Epoch 178/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1256e-04 - val_loss: 1.3211e-04
# Epoch 179/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0118e-04 - val_loss: 1.1892e-04
# Epoch 180/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1149e-05 - val_loss: 1.0615e-04
# Epoch 181/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1709e-05 - val_loss: 9.5724e-05
# Epoch 182/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3322e-05 - val_loss: 8.5687e-05
# Epoch 183/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5596e-05 - val_loss: 7.6917e-05
# Epoch 184/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8509e-05 - val_loss: 6.8114e-05
# Epoch 185/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2212e-05 - val_loss: 6.0920e-05
# Epoch 186/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6630e-05 - val_loss: 5.4476e-05
# Epoch 187/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1286e-05 - val_loss: 4.8126e-05
# Epoch 188/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6563e-05 - val_loss: 4.2506e-05
# Epoch 189/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2378e-05 - val_loss: 3.7935e-05
# Epoch 190/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8724e-05 - val_loss: 3.3032e-05
# Epoch 191/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5262e-05 - val_loss: 2.9415e-05
# Epoch 192/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2256e-05 - val_loss: 2.5928e-05
# Epoch 193/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9608e-05 - val_loss: 2.2697e-05
# Epoch 194/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7189e-05 - val_loss: 1.9929e-05
# Epoch 195/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5044e-05 - val_loss: 1.7366e-05
# Epoch 196/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3148e-05 - val_loss: 1.5305e-05
# Epoch 197/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1486e-05 - val_loss: 1.3082e-05
# Epoch 198/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9702e-06 - val_loss: 1.1458e-05
# Epoch 199/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7172e-06 - val_loss: 9.9535e-06
# Epoch 200/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5262e-06 - val_loss: 8.6697e-06
# Epoch 201/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5043e-06 - val_loss: 7.3774e-06
# Epoch 202/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6053e-06 - val_loss: 6.4018e-06
# Epoch 203/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8255e-06 - val_loss: 5.4729e-06
# Epoch 204/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1421e-06 - val_loss: 4.7639e-06
# Epoch 205/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5458e-06 - val_loss: 4.0800e-06
# Epoch 206/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0441e-06 - val_loss: 3.5149e-06
# Epoch 207/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5922e-06 - val_loss: 2.9540e-06
# Epoch 208/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2057e-06 - val_loss: 2.4816e-06
# Epoch 209/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8738e-06 - val_loss: 2.1267e-06
# Epoch 210/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5883e-06 - val_loss: 1.8217e-06
# Epoch 211/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3421e-06 - val_loss: 1.5143e-06
# Epoch 212/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1294e-06 - val_loss: 1.2816e-06
# Epoch 213/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5211e-07 - val_loss: 1.0736e-06
# Epoch 214/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9888e-07 - val_loss: 9.0009e-07
# Epoch 215/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6651e-07 - val_loss: 7.4942e-07
# Epoch 216/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5771e-07 - val_loss: 6.1054e-07
# Epoch 217/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6104e-07 - val_loss: 5.2381e-07
# Epoch 218/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8312e-07 - val_loss: 4.3236e-07
# Epoch 219/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1679e-07 - val_loss: 3.5233e-07
# Epoch 220/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6124e-07 - val_loss: 2.9290e-07
# Epoch 221/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1432e-07 - val_loss: 2.4091e-07
# Epoch 222/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7580e-07 - val_loss: 1.9655e-07
# Epoch 223/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4352e-07 - val_loss: 1.5731e-07
# Epoch 224/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1715e-07 - val_loss: 1.2863e-07
# Epoch 225/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4767e-08 - val_loss: 1.0521e-07
# Epoch 226/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6799e-08 - val_loss: 8.4975e-08
# Epoch 227/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2087e-08 - val_loss: 6.9476e-08
# Epoch 228/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9906e-08 - val_loss: 5.5250e-08
# Epoch 229/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0129e-08 - val_loss: 4.4505e-08
# Epoch 230/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2032e-08 - val_loss: 3.4168e-08
# Epoch 231/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5469e-08 - val_loss: 2.7883e-08
# Epoch 232/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0243e-08 - val_loss: 2.2024e-08
# Epoch 233/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6155e-08 - val_loss: 1.7127e-08
# Epoch 234/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2672e-08 - val_loss: 1.3932e-08
# Epoch 235/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8970e-09 - val_loss: 1.0607e-08
# Epoch 236/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7372e-09 - val_loss: 8.4563e-09
# Epoch 237/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0277e-09 - val_loss: 6.6008e-09
# Epoch 238/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6724e-09 - val_loss: 4.8968e-09
# Epoch 239/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6149e-09 - val_loss: 3.9287e-09
# Epoch 240/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8269e-09 - val_loss: 2.9034e-09
# Epoch 241/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1373e-09 - val_loss: 2.3576e-09
# Epoch 242/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6435e-09 - val_loss: 1.7521e-09
# Epoch 243/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2450e-09 - val_loss: 1.3388e-09
# Epoch 244/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4510e-10 - val_loss: 1.0041e-09
# Epoch 245/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1073e-10 - val_loss: 7.5781e-10
# Epoch 246/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3392e-10 - val_loss: 5.6605e-10
# Epoch 247/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9851e-10 - val_loss: 4.2824e-10
# Epoch 248/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9793e-10 - val_loss: 3.1312e-10
# Epoch 249/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1930e-10 - val_loss: 2.3562e-10
# Epoch 250/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6197e-10 - val_loss: 1.6962e-10
# Epoch 251/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1917e-10 - val_loss: 1.2145e-10
# Epoch 252/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6799e-11 - val_loss: 9.1608e-11
# Epoch 253/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3358e-11 - val_loss: 6.8052e-11
# Epoch 254/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5602e-11 - val_loss: 4.7682e-11
# Epoch 255/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2985e-11 - val_loss: 3.4150e-11
# Epoch 256/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3595e-11 - val_loss: 2.4766e-11
# Epoch 257/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6825e-11 - val_loss: 1.7445e-11
# Epoch 258/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1923e-11 - val_loss: 1.2359e-11
# Epoch 259/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4580e-12 - val_loss: 8.8351e-12
# Epoch 260/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9562e-12 - val_loss: 6.3376e-12
# Epoch 261/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1516e-12 - val_loss: 4.1050e-12
# Epoch 262/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8464e-12 - val_loss: 2.8851e-12
# Epoch 263/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9821e-12 - val_loss: 1.9520e-12
# Epoch 264/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3476e-12 - val_loss: 1.4185e-12
# Epoch 265/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3688e-13 - val_loss: 9.6477e-13
# Epoch 266/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6010e-13 - val_loss: 6.9380e-13
# Epoch 267/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4201e-13 - val_loss: 4.4132e-13
# Epoch 268/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0285e-13 - val_loss: 3.0322e-13
# Epoch 269/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1301e-13 - val_loss: 2.5464e-13
# Epoch 270/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8023e-13 - val_loss: 2.1000e-13
# Epoch 271/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4089e-13 - val_loss: 1.5996e-13
# Epoch 272/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1676e-13 - val_loss: 1.3865e-13
# Epoch 273/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3443e-14 - val_loss: 1.1651e-13
# Epoch 274/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7988e-14 - val_loss: 1.1595e-13
# Epoch 275/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7296e-14 - val_loss: 1.1514e-13
# Epoch 276/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7199e-14 - val_loss: 1.1208e-13
# Epoch 277/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7278e-14 - val_loss: 1.1721e-13
# Epoch 278/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7215e-14 - val_loss: 1.1073e-13
# Epoch 279/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5881e-14 - val_loss: 1.1551e-13
# Epoch 280/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5222e-14 - val_loss: 1.1049e-13
# Epoch 281/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5301e-14 - val_loss: 1.1551e-13
# Epoch 282/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5243e-14 - val_loss: 1.0865e-13
# Epoch 283/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5175e-14 - val_loss: 1.0865e-13
# Epoch 284/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6266e-14 - val_loss: 1.0979e-13
# Epoch 285/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1353e-14 - val_loss: 9.3841e-14
# Epoch 286/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3390e-14 - val_loss: 9.3049e-14
# Epoch 287/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2951e-14 - val_loss: 9.3841e-14
# Epoch 288/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1991e-14 - val_loss: 8.6842e-14
# Epoch 289/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1860e-14 - val_loss: 7.7986e-14
# Epoch 290/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8542e-14 - val_loss: 7.5623e-14
# Epoch 291/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8036e-14 - val_loss: 7.5623e-14
# Epoch 292/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9101e-14 - val_loss: 7.8381e-14
# Epoch 293/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8501e-14 - val_loss: 7.5623e-14
# Epoch 294/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8474e-14 - val_loss: 7.7619e-14
# Epoch 295/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6710e-14 - val_loss: 6.9593e-14
# Epoch 296/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3455e-14 - val_loss: 6.4035e-14
# Epoch 297/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0340e-14 - val_loss: 7.4767e-14
# Epoch 298/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1126e-14 - val_loss: 6.3718e-14
# Epoch 299/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0949e-14 - val_loss: 6.5578e-14
# Epoch 300/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0956e-14 - val_loss: 6.5183e-14
# Epoch 301/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1423e-14 - val_loss: 6.3648e-14
# Epoch 302/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8408e-14 - val_loss: 5.2280e-14
# Epoch 303/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6130e-14 - val_loss: 4.4052e-14
# Epoch 304/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0625e-14 - val_loss: 3.7807e-14
# Epoch 305/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8766e-14 - val_loss: 3.7114e-14
# Epoch 306/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8613e-14 - val_loss: 3.7114e-14
# Epoch 307/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8693e-14 - val_loss: 3.6672e-14
# Epoch 308/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8825e-14 - val_loss: 3.7114e-14
# Epoch 309/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8765e-14 - val_loss: 3.8262e-14
# Epoch 310/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9128e-14 - val_loss: 3.5383e-14
# Epoch 311/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9070e-14 - val_loss: 3.6672e-14
# Epoch 312/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8645e-14 - val_loss: 3.8968e-14
# Epoch 313/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8806e-14 - val_loss: 4.0622e-14
# Epoch 314/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9108e-14 - val_loss: 3.8262e-14
# Epoch 315/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8847e-14 - val_loss: 3.8968e-14
# Epoch 316/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8558e-14 - val_loss: 3.6356e-14
# Epoch 317/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8890e-14 - val_loss: 3.7114e-14
# Epoch 318/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8640e-14 - val_loss: 3.8262e-14
# Epoch 319/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8959e-14 - val_loss: 3.6672e-14
# Epoch 320/500
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9154e-14 - val_loss: 3.5539e-14

# %% [markdown]
# We can use the returned history object to view the training and validation loss as a function of the training epochs. As training continues we can see that again the validation loss reduces and we end up with a model that has generalized to the training data.

# %%
# plot the losses
plt.figure()
plt.semilogy(history.history['loss'])
plt.semilogy(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.xlabel('Epochs')
plt.title('Loss functions')
plt.show()

# %% [markdown]
# Optionally, we can view the performance of our model on our data by plotting the models predictions. In general, training an accurate model will be a function of many variables including choice of activation function, number of layers, number of neurons and the structure of the training data.

# %%
# %%
# Plot the error between the actual and predicted points
nn_out = linn_model.predict(inputs)
fig, axs = plt.subplots(2)
fig.suptitle('Predicted output')
axs[0].plot(out, label='Desired')
axs[0].plot(nn_out, '--', label='Model output')
axs[0].legend()
axs[1].plot(nn_out - out, label='Absolute Error')
axs[1].legend()
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step

# %% [markdown]
# Note the scale on the plot mapping the difference between model output and desired output.

# %% [markdown]
# # Step 3: Save the model to disk for use in the Moku Neural Network instrument.
#
# The neural network is completely described by its weights and biases. In this simple case, we can inspect these values and compare them to the function that was used to generate the data in the first place. Note that it has almost exactly learned the original function.

# %%
# Print model weights for interest and education
ii = 0
for layer in history.model.layers:
    if layer.get_weights():
        print(
            f'{ii}: ',
            'Weights',
            layer.get_weights()[0].flatten().tolist(),
            ', Biases',
            layer.get_weights()[1].flatten().tolist(),
        )
        ii = ii + 1

# Save the model to a .linn file
save_linn(linn_model.model, input_channels=3, output_channels=1, file_name='Sum.linn')
# Out:
# 0:  Weights [0.10000021010637283, 0.19999957084655762, 0.299999475479126] , Biases [0.09999997913837433]
# Skipping layer 0 with type <class 'keras.src.layers.core.input_layer.InputLayer'>
# Skipping layer 2 with type <class 'moku.nn._linn.OutputClipLayer'>
# Network latency approx. 6 cycles
